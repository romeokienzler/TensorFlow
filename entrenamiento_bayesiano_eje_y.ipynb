# %% [markdown]
# <a href="https://colab.research.google.com/github/naldo14/TensorFlow/blob/master/entrenamiento_bayesiano_eje_y.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## importo las librerias
import h5py
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
from tensorflow import keras
tfd = tfp.distributions
tfpl = tfp.layers

# %%
## hago el mounting
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Proceso de carga de los datos

# %% [markdown]
# ## data sobre el eje y

# %%
#creo el h5py de las features
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/features_y"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'r') as hf:
    y_features = hf['features_y'][:]

# %%
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/y_targets"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'r') as hf:
    y_targets = hf['y_targets'][:]

# %%
y_targets.shape
# Out:
# (55,)

# %% [markdown]
# ### data sobre el eje *x*

# %%
#creo el h5py de las features
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/features_x"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'r') as hf:
   x_features = hf['features_x'][:]

# %%
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/x_targets"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'r') as hf:
    x_targets = hf['x_targets'][:]

# %%
## data sets but using y-axis measures
from sklearn.model_selection import train_test_split
# Assuming x is your dataset with shape (70, 14) and y is your labels
x_train, x_test, y_train, y_test = train_test_split(y_features, y_targets, test_size=0.3, random_state=42)
print("corrida usando el eje y")
# Out:
# corrida usando el eje y

# %%
## data sets but using x-axis measures
from sklearn.model_selection import train_test_split
# Assuming x is your dataset with shape (70, 14) and y is your labels
x_train, x_test, y_train, y_test = train_test_split(x_features, x_targets, test_size=0.3, random_state=42)
print("corrida usando el eje x")

# %%
del x_train, x_test, y_train, y_test

# %% [markdown]
# ### Creacion de la BNN

# %%
## def prior weight distribution N(1,0) and not trainable
# Define the prior weight distribution N(0, 1)
def prior(kernel_size, bias_size, dtype=None):
    n = kernel_size + bias_size
    prior_model = keras.Sequential(
        [
            tfp.layers.DistributionLambda(
                lambda t: tfp.distributions.MultivariateNormalDiag(
                    loc=tf.zeros(n), scale_diag=tf.ones(n)
                )
            )
        ]
    )
    return prior_model

# %%
# Define the posterior weight distribution Multivariate Gaussian distribution
def posterior(kernel_size, bias_size, dtype=None):
    n = kernel_size + bias_size
    posterior_model = keras.Sequential(
        [
            tfp.layers.VariableLayer(
                tfp.layers.MultivariateNormalTriL.params_size(n), dtype=dtype
            ),
            tfp.layers.MultivariateNormalTriL(n),
        ]
    )
    return posterior_model

# %%
# Define the BNN model
model = tf.keras.Sequential([
    tfpl.DenseVariational(
        input_shape=(14,),
        units=30,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        kl_weight=1/x_train.shape[0],  # KL Weight
        # kl_use_exact=True
    ),

       tfpl.DenseVariational(
        units=25,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),

    tfpl.DenseVariational(
        units=20,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),

    tfpl.DenseVariational(
        units=15,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),


      tfpl.DenseVariational(
        units=12,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),
    tfpl.DenseVariational(
        units=8,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),
    tfpl.DenseVariational(
        units=5,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),
    tfpl.DenseVariational(
        units=1,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='sigmoid',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),
])

# %%
del model

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_variational_53 (Dens  (None, 30)                101925
#  eVariational)
#
#  dense_variational_54 (Dens  (None, 25)                301475
#  eVariational)
#
#  dense_variational_55 (Dens  (None, 20)                135980
#  eVariational)
#
#  dense_variational_56 (Dens  (None, 15)                50085
#  eVariational)
#
#  dense_variational_57 (Dens  (None, 12)                18720
#  eVariational)
#
#  dense_variational_58 (Dens  (None, 8)                 5564
#  eVariational)
#
#  dense_variational_59 (Dens  (None, 5)                 1080
#  eVariational)
#
#  dense_variational_60 (Dens  (None, 1)                 27
#  eVariational)
#
# =================================================================
# Total params: 614856 (2.35 MB)
# Trainable params: 614856 (2.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.FalseNegatives(), tf.keras.metrics.FalsePositives()])

# Train the model
history = model.fit(x_train, y_train, epochs=1000, verbose=2)

# Evaluate the model on the test data
test_loss, test_accuracy, false_negatives, false_positives = model.evaluate(x_test, y_test)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
print(f"False Negatives: {false_negatives:.0f}")
print(f"False Positives: {false_positives:.0f}")

# Make predictions on test data
y_pred = model.predict(x_test)
y_pred_binary = (y_pred >= 0.5).astype(int)

# Calculate confusion matrix
confusion = confusion_matrix(y_test, y_pred_binary)
print("Confusion Matrix:")
print(confusion)
# Out:
# Epoch 1/1000
# 2/2 - 10s - loss: 12.0206 - accuracy: 0.6316 - false_negatives_6: 0.0000e+00 - false_positives_6: 14.0000 - 10s/epoch - 5s/step
# Epoch 2/1000
# 2/2 - 0s - loss: 19.1026 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 145ms/epoch - 72ms/step
# Epoch 3/1000
# 2/2 - 0s - loss: 7.5034 - accuracy: 0.4474 - false_negatives_6: 18.0000 - false_positives_6: 3.0000 - 132ms/epoch - 66ms/step
# Epoch 4/1000
# 2/2 - 0s - loss: 19.0703 - accuracy: 0.3684 - false_negatives_6: 23.0000 - false_positives_6: 1.0000 - 147ms/epoch - 74ms/step
# Epoch 5/1000
# 2/2 - 0s - loss: 12.2500 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 142ms/epoch - 71ms/step
# Epoch 6/1000
# 2/2 - 0s - loss: 52.1066 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 138ms/epoch - 69ms/step
# Epoch 7/1000
# 2/2 - 0s - loss: 29.7508 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 129ms/epoch - 65ms/step
# Epoch 8/1000
# 2/2 - 0s - loss: 21.4059 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 139ms/epoch - 69ms/step
# Epoch 9/1000
# 2/2 - 0s - loss: 32.0880 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 126ms/epoch - 63ms/step
# Epoch 10/1000
# 2/2 - 0s - loss: 12.2285 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 130ms/epoch - 65ms/step
# Epoch 11/1000
# 2/2 - 0s - loss: 18.8662 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 139ms/epoch - 69ms/step
# Epoch 12/1000
# 2/2 - 0s - loss: 82.3438 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 133ms/epoch - 66ms/step
# Epoch 13/1000
# 2/2 - 0s - loss: 15.5985 - accuracy: 0.3158 - false_negatives_6: 16.0000 - false_positives_6: 10.0000 - 129ms/epoch - 65ms/step
# Epoch 14/1000
# 2/2 - 0s - loss: 12.6959 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 129ms/epoch - 65ms/step
# Epoch 15/1000
# 2/2 - 0s - loss: 15.7896 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 134ms/epoch - 67ms/step
# Epoch 16/1000
# 2/2 - 0s - loss: 10.5168 - accuracy: 0.2105 - false_negatives_6: 20.0000 - false_positives_6: 10.0000 - 129ms/epoch - 64ms/step
# Epoch 17/1000
# 2/2 - 0s - loss: 12.8955 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 135ms/epoch - 67ms/step
# Epoch 18/1000
# 2/2 - 0s - loss: 27.8668 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 139ms/epoch - 69ms/step
# Epoch 19/1000
# 2/2 - 0s - loss: 27.8461 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 136ms/epoch - 68ms/step
# Epoch 20/1000
# 2/2 - 0s - loss: 9.3281 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 143ms/epoch - 71ms/step
# Epoch 21/1000
# 2/2 - 0s - loss: 17.3514 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 138ms/epoch - 69ms/step
# Epoch 22/1000
# 2/2 - 0s - loss: 16.0978 - accuracy: 0.3421 - false_negatives_6: 20.0000 - false_positives_6: 5.0000 - 129ms/epoch - 64ms/step
# Epoch 23/1000
# 2/2 - 0s - loss: 17.3434 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 129ms/epoch - 65ms/step
# Epoch 24/1000
# 2/2 - 0s - loss: 87.3577 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 131ms/epoch - 66ms/step
# Epoch 25/1000
# 2/2 - 0s - loss: 18.3136 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 136ms/epoch - 68ms/step
# Epoch 26/1000
# 2/2 - 0s - loss: 56.6705 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 142ms/epoch - 71ms/step
# Epoch 27/1000
# 2/2 - 0s - loss: 20.9276 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 118ms/epoch - 59ms/step
# Epoch 28/1000
# 2/2 - 0s - loss: 25.2636 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 70ms/epoch - 35ms/step
# Epoch 29/1000
# 2/2 - 0s - loss: 21.2256 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 66ms/epoch - 33ms/step
# Epoch 30/1000
# 2/2 - 0s - loss: 23.6338 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 71ms/epoch - 36ms/step
# Epoch 31/1000
# 2/2 - 0s - loss: 19.2801 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 84ms/epoch - 42ms/step
# Epoch 32/1000
# 2/2 - 0s - loss: 26.6868 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 70ms/epoch - 35ms/step
# Epoch 33/1000
# 2/2 - 0s - loss: 37.1609 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 70ms/epoch - 35ms/step
# Epoch 34/1000
# 2/2 - 0s - loss: 20.8851 - accuracy: 0.3684 - false_negatives_6: 23.0000 - false_positives_6: 1.0000 - 74ms/epoch - 37ms/step
# Epoch 35/1000
# 2/2 - 0s - loss: 9.8442 - accuracy: 0.7632 - false_negatives_6: 2.0000 - false_positives_6: 7.0000 - 66ms/epoch - 33ms/step
# Epoch 36/1000
# 2/2 - 0s - loss: 22.9957 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 72ms/epoch - 36ms/step
# Epoch 37/1000
# 2/2 - 0s - loss: 142.4279 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 72ms/epoch - 36ms/step
# Epoch 38/1000
# 2/2 - 0s - loss: 12.0863 - accuracy: 0.4737 - false_negatives_6: 16.0000 - false_positives_6: 4.0000 - 69ms/epoch - 34ms/step
# Epoch 39/1000
# 2/2 - 0s - loss: 20.9496 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 81ms/epoch - 40ms/step
# Epoch 40/1000
# 2/2 - 0s - loss: 7.5757 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 76ms/epoch - 38ms/step
# Epoch 41/1000
# 2/2 - 0s - loss: 11.5352 - accuracy: 0.5789 - false_negatives_6: 15.0000 - false_positives_6: 1.0000 - 72ms/epoch - 36ms/step
# Epoch 42/1000
# 2/2 - 0s - loss: 12.4488 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 72ms/epoch - 36ms/step
# Epoch 43/1000
# 2/2 - 0s - loss: 34.4999 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 70ms/epoch - 35ms/step
# Epoch 44/1000
# 2/2 - 0s - loss: 11.4328 - accuracy: 0.5526 - false_negatives_6: 5.0000 - false_positives_6: 12.0000 - 66ms/epoch - 33ms/step
# Epoch 45/1000
# 2/2 - 0s - loss: 45.6618 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 70ms/epoch - 35ms/step
# Epoch 46/1000
# 2/2 - 0s - loss: 30.6615 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 69ms/epoch - 35ms/step
# Epoch 47/1000
# 2/2 - 0s - loss: 51.1134 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 74ms/epoch - 37ms/step
# Epoch 48/1000
# 2/2 - 0s - loss: 61.2332 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 70ms/epoch - 35ms/step
# Epoch 49/1000
# 2/2 - 0s - loss: 50.7659 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 71ms/epoch - 35ms/step
# Epoch 50/1000
# 2/2 - 0s - loss: 14.2010 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 65ms/epoch - 32ms/step
# Epoch 51/1000
# 2/2 - 0s - loss: 29.4985 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 68ms/epoch - 34ms/step
# Epoch 52/1000
# 2/2 - 0s - loss: 41.7397 - accuracy: 0.2895 - false_negatives_6: 13.0000 - false_positives_6: 14.0000 - 87ms/epoch - 43ms/step
# Epoch 53/1000
# 2/2 - 0s - loss: 41.9548 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 66ms/epoch - 33ms/step
# Epoch 54/1000
# 2/2 - 0s - loss: 124.8984 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 69ms/epoch - 35ms/step
# Epoch 55/1000
# 2/2 - 0s - loss: 43.3028 - accuracy: 0.3158 - false_negatives_6: 21.0000 - false_positives_6: 5.0000 - 67ms/epoch - 34ms/step
# Epoch 56/1000
# 2/2 - 0s - loss: 9.8844 - accuracy: 0.2895 - false_negatives_6: 12.0000 - false_positives_6: 15.0000 - 75ms/epoch - 38ms/step
# Epoch 57/1000
# 2/2 - 0s - loss: 23.3457 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 67ms/epoch - 33ms/step
# Epoch 58/1000
# 2/2 - 0s - loss: 26.5214 - accuracy: 0.3684 - false_negatives_6: 23.0000 - false_positives_6: 1.0000 - 67ms/epoch - 34ms/step
# Epoch 59/1000
# 2/2 - 0s - loss: 122.7226 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 69ms/epoch - 34ms/step
# Epoch 60/1000
# 2/2 - 0s - loss: 45.7722 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 68ms/epoch - 34ms/step
# Epoch 61/1000
# 2/2 - 0s - loss: 48.9596 - accuracy: 0.3158 - false_negatives_6: 22.0000 - false_positives_6: 4.0000 - 66ms/epoch - 33ms/step
# Epoch 62/1000
# 2/2 - 0s - loss: 30.7226 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 71ms/epoch - 36ms/step
# Epoch 63/1000
# 2/2 - 0s - loss: 18.8577 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 75ms/epoch - 37ms/step
# Epoch 64/1000
# 2/2 - 0s - loss: 9.3447 - accuracy: 0.7368 - false_negatives_6: 4.0000 - false_positives_6: 6.0000 - 65ms/epoch - 33ms/step
# Epoch 65/1000
# 2/2 - 0s - loss: 11.8854 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 80ms/epoch - 40ms/step
# Epoch 66/1000
# 2/2 - 0s - loss: 17.8819 - accuracy: 0.3421 - false_negatives_6: 19.0000 - false_positives_6: 6.0000 - 75ms/epoch - 37ms/step
# Epoch 67/1000
# 2/2 - 0s - loss: 12.5356 - accuracy: 0.3421 - false_negatives_6: 23.0000 - false_positives_6: 2.0000 - 64ms/epoch - 32ms/step
# Epoch 68/1000
# 2/2 - 0s - loss: 11.1726 - accuracy: 0.4737 - false_negatives_6: 8.0000 - false_positives_6: 12.0000 - 63ms/epoch - 32ms/step
# Epoch 69/1000
# 2/2 - 0s - loss: 34.7902 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 78ms/epoch - 39ms/step
# Epoch 70/1000
# 2/2 - 0s - loss: 25.1065 - accuracy: 0.4474 - false_negatives_6: 6.0000 - false_positives_6: 15.0000 - 66ms/epoch - 33ms/step
# Epoch 71/1000
# 2/2 - 0s - loss: 13.3749 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 68ms/epoch - 34ms/step
# Epoch 72/1000
# 2/2 - 0s - loss: 46.8279 - accuracy: 0.5526 - false_negatives_6: 6.0000 - false_positives_6: 11.0000 - 75ms/epoch - 38ms/step
# Epoch 73/1000
# 2/2 - 0s - loss: 29.2847 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 66ms/epoch - 33ms/step
# Epoch 74/1000
# 2/2 - 0s - loss: 8.5920 - accuracy: 0.3684 - false_negatives_6: 23.0000 - false_positives_6: 1.0000 - 65ms/epoch - 33ms/step
# Epoch 75/1000
# 2/2 - 0s - loss: 15.3553 - accuracy: 0.4737 - false_negatives_6: 20.0000 - false_positives_6: 0.0000e+00 - 68ms/epoch - 34ms/step
# Epoch 76/1000
# 2/2 - 0s - loss: 48.4734 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 70ms/epoch - 35ms/step
# Epoch 77/1000
# 2/2 - 0s - loss: 112.9887 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 66ms/epoch - 33ms/step
# Epoch 78/1000
# 2/2 - 0s - loss: 12.9087 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 64ms/epoch - 32ms/step
# Epoch 79/1000
# 2/2 - 0s - loss: 29.2284 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 98ms/epoch - 49ms/step
# Epoch 80/1000
# 2/2 - 0s - loss: 20.3574 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 73ms/epoch - 37ms/step
# Epoch 81/1000
# 2/2 - 0s - loss: 14.1419 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 77ms/epoch - 39ms/step
# Epoch 82/1000
# 2/2 - 0s - loss: 11.0944 - accuracy: 0.4737 - false_negatives_6: 19.0000 - false_positives_6: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 83/1000
# 2/2 - 0s - loss: 18.5143 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 70ms/epoch - 35ms/step
# Epoch 84/1000
# 2/2 - 0s - loss: 90.3668 - accuracy: 0.4211 - false_negatives_6: 22.0000 - false_positives_6: 0.0000e+00 - 65ms/epoch - 32ms/step
# Epoch 85/1000
# 2/2 - 0s - loss: 24.7810 - accuracy: 0.5789 - false_negatives_6: 2.0000 - false_positives_6: 14.0000 - 68ms/epoch - 34ms/step
# Epoch 86/1000
# 2/2 - 0s - loss: 29.9077 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 65ms/epoch - 33ms/step
# Epoch 87/1000
# 2/2 - 0s - loss: 28.9490 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 63ms/epoch - 32ms/step
# Epoch 88/1000
# 2/2 - 0s - loss: 21.7645 - accuracy: 0.5000 - false_negatives_6: 4.0000 - false_positives_6: 15.0000 - 64ms/epoch - 32ms/step
# Epoch 89/1000
# 2/2 - 0s - loss: 114.0346 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 77ms/epoch - 38ms/step
# Epoch 90/1000
# 2/2 - 0s - loss: 18.0226 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 64ms/epoch - 32ms/step
# Epoch 91/1000
# 2/2 - 0s - loss: 35.3603 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 92/1000
# 2/2 - 0s - loss: 14.7380 - accuracy: 0.5789 - false_negatives_6: 1.0000 - false_positives_6: 15.0000 - 88ms/epoch - 44ms/step
# Epoch 93/1000
# 2/2 - 0s - loss: 76.0087 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 65ms/epoch - 32ms/step
# Epoch 94/1000
# 2/2 - 0s - loss: 9.8643 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 65ms/epoch - 33ms/step
# Epoch 95/1000
# 2/2 - 0s - loss: 62.7692 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 64ms/epoch - 32ms/step
# Epoch 96/1000
# 2/2 - 0s - loss: 17.2482 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 75ms/epoch - 37ms/step
# Epoch 97/1000
# 2/2 - 0s - loss: 74.0365 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 67ms/epoch - 34ms/step
# Epoch 98/1000
# 2/2 - 0s - loss: 19.6735 - accuracy: 0.3421 - false_negatives_6: 13.0000 - false_positives_6: 12.0000 - 66ms/epoch - 33ms/step
# Epoch 99/1000
# 2/2 - 0s - loss: 15.4427 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 68ms/epoch - 34ms/step
# Epoch 100/1000
# 2/2 - 0s - loss: 43.2615 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 68ms/epoch - 34ms/step
# Epoch 101/1000
# 2/2 - 0s - loss: 10.6616 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 76ms/epoch - 38ms/step
# Epoch 102/1000
# 2/2 - 0s - loss: 201.9733 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 78ms/epoch - 39ms/step
# Epoch 103/1000
# 2/2 - 0s - loss: 40.6555 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 71ms/epoch - 35ms/step
# Epoch 104/1000
# 2/2 - 0s - loss: 80.2946 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 65ms/epoch - 33ms/step
# Epoch 105/1000
# 2/2 - 0s - loss: 56.9908 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 77ms/epoch - 39ms/step
# Epoch 106/1000
# 2/2 - 0s - loss: 9.5637 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 69ms/epoch - 35ms/step
# Epoch 107/1000
# 2/2 - 0s - loss: 10.5417 - accuracy: 0.6316 - false_negatives_6: 1.0000 - false_positives_6: 13.0000 - 65ms/epoch - 32ms/step
# Epoch 108/1000
# 2/2 - 0s - loss: 72.6158 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 66ms/epoch - 33ms/step
# Epoch 109/1000
# 2/2 - 0s - loss: 14.9936 - accuracy: 0.7105 - false_negatives_6: 11.0000 - false_positives_6: 0.0000e+00 - 66ms/epoch - 33ms/step
# Epoch 110/1000
# 2/2 - 0s - loss: 12.4504 - accuracy: 0.6579 - false_negatives_6: 6.0000 - false_positives_6: 7.0000 - 66ms/epoch - 33ms/step
# Epoch 111/1000
# 2/2 - 0s - loss: 9.7958 - accuracy: 0.7105 - false_negatives_6: 0.0000e+00 - false_positives_6: 11.0000 - 64ms/epoch - 32ms/step
# Epoch 112/1000
# 2/2 - 0s - loss: 36.0642 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 67ms/epoch - 33ms/step
# Epoch 113/1000
# 2/2 - 0s - loss: 20.7184 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 72ms/epoch - 36ms/step
# Epoch 114/1000
# 2/2 - 0s - loss: 38.4308 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 67ms/epoch - 34ms/step
# Epoch 115/1000
# 2/2 - 0s - loss: 27.9548 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 67ms/epoch - 33ms/step
# Epoch 116/1000
# 2/2 - 0s - loss: 9.3672 - accuracy: 0.8421 - false_negatives_6: 2.0000 - false_positives_6: 4.0000 - 81ms/epoch - 40ms/step
# Epoch 117/1000
# 2/2 - 0s - loss: 92.6972 - accuracy: 0.5526 - false_negatives_6: 7.0000 - false_positives_6: 10.0000 - 77ms/epoch - 39ms/step
# Epoch 118/1000
# 2/2 - 0s - loss: 10.1043 - accuracy: 0.5526 - false_negatives_6: 2.0000 - false_positives_6: 15.0000 - 66ms/epoch - 33ms/step
# Epoch 119/1000
# 2/2 - 0s - loss: 13.3680 - accuracy: 0.3947 - false_negatives_6: 22.0000 - false_positives_6: 1.0000 - 85ms/epoch - 43ms/step
# Epoch 120/1000
# 2/2 - 0s - loss: 28.1332 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 64ms/epoch - 32ms/step
# Epoch 121/1000
# 2/2 - 0s - loss: 16.1425 - accuracy: 0.6579 - false_negatives_6: 1.0000 - false_positives_6: 12.0000 - 70ms/epoch - 35ms/step
# Epoch 122/1000
# 2/2 - 0s - loss: 79.4757 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 74ms/epoch - 37ms/step
# Epoch 123/1000
# 2/2 - 0s - loss: 18.3977 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 66ms/epoch - 33ms/step
# Epoch 124/1000
# 2/2 - 0s - loss: 10.0955 - accuracy: 0.6053 - false_negatives_6: 2.0000 - false_positives_6: 13.0000 - 65ms/epoch - 32ms/step
# Epoch 125/1000
# 2/2 - 0s - loss: 134.9258 - accuracy: 0.6053 - false_negatives_6: 2.0000 - false_positives_6: 13.0000 - 63ms/epoch - 32ms/step
# Epoch 126/1000
# 2/2 - 0s - loss: 19.4283 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 75ms/epoch - 37ms/step
# Epoch 127/1000
# 2/2 - 0s - loss: 13.4866 - accuracy: 0.5526 - false_negatives_6: 5.0000 - false_positives_6: 12.0000 - 66ms/epoch - 33ms/step
# Epoch 128/1000
# 2/2 - 0s - loss: 10.3412 - accuracy: 0.7105 - false_negatives_6: 1.0000 - false_positives_6: 10.0000 - 69ms/epoch - 35ms/step
# Epoch 129/1000
# 2/2 - 0s - loss: 107.0974 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 70ms/epoch - 35ms/step
# Epoch 130/1000
# 2/2 - 0s - loss: 14.1488 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 66ms/epoch - 33ms/step
# Epoch 131/1000
# 2/2 - 0s - loss: 25.2438 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 68ms/epoch - 34ms/step
# Epoch 132/1000
# 2/2 - 0s - loss: 31.3284 - accuracy: 0.1842 - false_negatives_6: 22.0000 - false_positives_6: 9.0000 - 77ms/epoch - 39ms/step
# Epoch 133/1000
# 2/2 - 0s - loss: 48.6491 - accuracy: 0.7105 - false_negatives_6: 1.0000 - false_positives_6: 10.0000 - 65ms/epoch - 32ms/step
# Epoch 134/1000
# 2/2 - 0s - loss: 24.1159 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 68ms/epoch - 34ms/step
# Epoch 135/1000
# 2/2 - 0s - loss: 18.1744 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 68ms/epoch - 34ms/step
# Epoch 136/1000
# 2/2 - 0s - loss: 22.3553 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 68ms/epoch - 34ms/step
# Epoch 137/1000
# 2/2 - 0s - loss: 14.6931 - accuracy: 0.5789 - false_negatives_6: 2.0000 - false_positives_6: 14.0000 - 86ms/epoch - 43ms/step
# Epoch 138/1000
# 2/2 - 0s - loss: 22.5290 - accuracy: 0.4211 - false_negatives_6: 22.0000 - false_positives_6: 0.0000e+00 - 75ms/epoch - 38ms/step
# Epoch 139/1000
# 2/2 - 0s - loss: 10.0044 - accuracy: 0.5526 - false_negatives_6: 15.0000 - false_positives_6: 2.0000 - 67ms/epoch - 34ms/step
# Epoch 140/1000
# 2/2 - 0s - loss: 11.0293 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 77ms/epoch - 39ms/step
# Epoch 141/1000
# 2/2 - 0s - loss: 18.0364 - accuracy: 0.5526 - false_negatives_6: 3.0000 - false_positives_6: 14.0000 - 78ms/epoch - 39ms/step
# Epoch 142/1000
# 2/2 - 0s - loss: 15.2342 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 143/1000
# 2/2 - 0s - loss: 75.4519 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 71ms/epoch - 36ms/step
# Epoch 144/1000
# 2/2 - 0s - loss: 28.1965 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 66ms/epoch - 33ms/step
# Epoch 145/1000
# 2/2 - 0s - loss: 13.9900 - accuracy: 0.4211 - false_negatives_6: 21.0000 - false_positives_6: 1.0000 - 85ms/epoch - 43ms/step
# Epoch 146/1000
# 2/2 - 0s - loss: 16.4316 - accuracy: 0.4211 - false_negatives_6: 19.0000 - false_positives_6: 3.0000 - 73ms/epoch - 36ms/step
# Epoch 147/1000
# 2/2 - 0s - loss: 13.2925 - accuracy: 0.4211 - false_negatives_6: 20.0000 - false_positives_6: 2.0000 - 68ms/epoch - 34ms/step
# Epoch 148/1000
# 2/2 - 0s - loss: 15.0687 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 80ms/epoch - 40ms/step
# Epoch 149/1000
# 2/2 - 0s - loss: 27.2843 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 66ms/epoch - 33ms/step
# Epoch 150/1000
# 2/2 - 0s - loss: 17.3494 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 67ms/epoch - 33ms/step
# Epoch 151/1000
# 2/2 - 0s - loss: 33.4197 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 71ms/epoch - 36ms/step
# Epoch 152/1000
# 2/2 - 0s - loss: 15.8811 - accuracy: 0.4474 - false_negatives_6: 6.0000 - false_positives_6: 15.0000 - 66ms/epoch - 33ms/step
# Epoch 153/1000
# 2/2 - 0s - loss: 55.0614 - accuracy: 0.5526 - false_negatives_6: 17.0000 - false_positives_6: 0.0000e+00 - 73ms/epoch - 36ms/step
# Epoch 154/1000
# 2/2 - 0s - loss: 56.1044 - accuracy: 0.5263 - false_negatives_6: 3.0000 - false_positives_6: 15.0000 - 63ms/epoch - 32ms/step
# Epoch 155/1000
# 2/2 - 0s - loss: 23.6899 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 83ms/epoch - 41ms/step
# Epoch 156/1000
# 2/2 - 0s - loss: 47.1072 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 70ms/epoch - 35ms/step
# Epoch 157/1000
# 2/2 - 0s - loss: 12.4565 - accuracy: 0.6579 - false_negatives_6: 0.0000e+00 - false_positives_6: 13.0000 - 108ms/epoch - 54ms/step
# Epoch 158/1000
# 2/2 - 0s - loss: 13.5814 - accuracy: 0.5526 - false_negatives_6: 3.0000 - false_positives_6: 14.0000 - 121ms/epoch - 61ms/step
# Epoch 159/1000
# 2/2 - 0s - loss: 109.0839 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 141ms/epoch - 70ms/step
# Epoch 160/1000
# 2/2 - 0s - loss: 21.9107 - accuracy: 0.5526 - false_negatives_6: 6.0000 - false_positives_6: 11.0000 - 130ms/epoch - 65ms/step
# Epoch 161/1000
# 2/2 - 0s - loss: 23.9797 - accuracy: 0.5263 - false_negatives_6: 18.0000 - false_positives_6: 0.0000e+00 - 133ms/epoch - 67ms/step
# Epoch 162/1000
# 2/2 - 0s - loss: 16.0621 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 134ms/epoch - 67ms/step
# Epoch 163/1000
# 2/2 - 0s - loss: 14.1263 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 140ms/epoch - 70ms/step
# Epoch 164/1000
# 2/2 - 0s - loss: 16.9697 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 138ms/epoch - 69ms/step
# Epoch 165/1000
# 2/2 - 0s - loss: 26.1653 - accuracy: 0.5789 - false_negatives_6: 3.0000 - false_positives_6: 13.0000 - 145ms/epoch - 73ms/step
# Epoch 166/1000
# 2/2 - 0s - loss: 23.5605 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 133ms/epoch - 66ms/step
# Epoch 167/1000
# 2/2 - 0s - loss: 54.6657 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 134ms/epoch - 67ms/step
# Epoch 168/1000
# 2/2 - 0s - loss: 17.9305 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 132ms/epoch - 66ms/step
# Epoch 169/1000
# 2/2 - 0s - loss: 23.6508 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 137ms/epoch - 69ms/step
# Epoch 170/1000
# 2/2 - 0s - loss: 13.9698 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 120ms/epoch - 60ms/step
# Epoch 171/1000
# 2/2 - 0s - loss: 12.9726 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 116ms/epoch - 58ms/step
# Epoch 172/1000
# 2/2 - 0s - loss: 20.0753 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 113ms/epoch - 57ms/step
# Epoch 173/1000
# 2/2 - 0s - loss: 27.1400 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 142ms/epoch - 71ms/step
# Epoch 174/1000
# 2/2 - 0s - loss: 31.1395 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 131ms/epoch - 66ms/step
# Epoch 175/1000
# 2/2 - 0s - loss: 84.7154 - accuracy: 0.5789 - false_negatives_6: 3.0000 - false_positives_6: 13.0000 - 130ms/epoch - 65ms/step
# Epoch 176/1000
# 2/2 - 0s - loss: 36.2334 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 127ms/epoch - 64ms/step
# Epoch 177/1000
# 2/2 - 0s - loss: 13.0245 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 129ms/epoch - 65ms/step
# Epoch 178/1000
# 2/2 - 0s - loss: 12.8274 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 124ms/epoch - 62ms/step
# Epoch 179/1000
# 2/2 - 0s - loss: 10.9172 - accuracy: 0.7895 - false_negatives_6: 1.0000 - false_positives_6: 7.0000 - 125ms/epoch - 63ms/step
# Epoch 180/1000
# 2/2 - 0s - loss: 28.3048 - accuracy: 0.3158 - false_negatives_6: 22.0000 - false_positives_6: 4.0000 - 125ms/epoch - 62ms/step
# Epoch 181/1000
# 2/2 - 0s - loss: 16.3768 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 128ms/epoch - 64ms/step
# Epoch 182/1000
# 2/2 - 0s - loss: 11.3968 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 127ms/epoch - 63ms/step
# Epoch 183/1000
# 2/2 - 0s - loss: 17.3995 - accuracy: 0.6316 - false_negatives_6: 0.0000e+00 - false_positives_6: 14.0000 - 127ms/epoch - 64ms/step
# Epoch 184/1000
# 2/2 - 0s - loss: 25.5279 - accuracy: 0.5789 - false_negatives_6: 1.0000 - false_positives_6: 15.0000 - 128ms/epoch - 64ms/step
# Epoch 185/1000
# 2/2 - 0s - loss: 10.9235 - accuracy: 0.4737 - false_negatives_6: 10.0000 - false_positives_6: 10.0000 - 130ms/epoch - 65ms/step
# Epoch 186/1000
# 2/2 - 0s - loss: 31.7661 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 128ms/epoch - 64ms/step
# Epoch 187/1000
# 2/2 - 0s - loss: 17.8584 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 130ms/epoch - 65ms/step
# Epoch 188/1000
# 2/2 - 0s - loss: 75.7111 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 130ms/epoch - 65ms/step
# Epoch 189/1000
# 2/2 - 0s - loss: 28.3198 - accuracy: 0.4474 - false_negatives_6: 20.0000 - false_positives_6: 1.0000 - 135ms/epoch - 67ms/step
# Epoch 190/1000
# 2/2 - 0s - loss: 24.6239 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 127ms/epoch - 63ms/step
# Epoch 191/1000
# 2/2 - 0s - loss: 23.8096 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 139ms/epoch - 70ms/step
# Epoch 192/1000
# 2/2 - 0s - loss: 37.9520 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 116ms/epoch - 58ms/step
# Epoch 193/1000
# 2/2 - 0s - loss: 24.8597 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 84ms/epoch - 42ms/step
# Epoch 194/1000
# 2/2 - 0s - loss: 25.1360 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 73ms/epoch - 36ms/step
# Epoch 195/1000
# 2/2 - 0s - loss: 12.0576 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 65ms/epoch - 32ms/step
# Epoch 196/1000
# 2/2 - 0s - loss: 20.5721 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 72ms/epoch - 36ms/step
# Epoch 197/1000
# 2/2 - 0s - loss: 40.8454 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 70ms/epoch - 35ms/step
# Epoch 198/1000
# 2/2 - 0s - loss: 27.6164 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 63ms/epoch - 32ms/step
# Epoch 199/1000
# 2/2 - 0s - loss: 12.0928 - accuracy: 0.5789 - false_negatives_6: 2.0000 - false_positives_6: 14.0000 - 85ms/epoch - 43ms/step
# Epoch 200/1000
# 2/2 - 0s - loss: 10.2566 - accuracy: 0.5526 - false_negatives_6: 7.0000 - false_positives_6: 10.0000 - 65ms/epoch - 33ms/step
# Epoch 201/1000
# 2/2 - 0s - loss: 54.8475 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 65ms/epoch - 32ms/step
# Epoch 202/1000
# 2/2 - 0s - loss: 26.7452 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 72ms/epoch - 36ms/step
# Epoch 203/1000
# 2/2 - 0s - loss: 11.3698 - accuracy: 0.5526 - false_negatives_6: 5.0000 - false_positives_6: 12.0000 - 63ms/epoch - 32ms/step
# Epoch 204/1000
# 2/2 - 0s - loss: 16.5457 - accuracy: 0.3684 - false_negatives_6: 17.0000 - false_positives_6: 7.0000 - 61ms/epoch - 31ms/step
# Epoch 205/1000
# 2/2 - 0s - loss: 83.9394 - accuracy: 0.6053 - false_negatives_6: 1.0000 - false_positives_6: 14.0000 - 68ms/epoch - 34ms/step
# Epoch 206/1000
# 2/2 - 0s - loss: 10.4308 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 78ms/epoch - 39ms/step
# Epoch 207/1000
# 2/2 - 0s - loss: 15.7531 - accuracy: 0.6579 - false_negatives_6: 0.0000e+00 - false_positives_6: 13.0000 - 74ms/epoch - 37ms/step
# Epoch 208/1000
# 2/2 - 0s - loss: 20.2997 - accuracy: 0.5526 - false_negatives_6: 2.0000 - false_positives_6: 15.0000 - 76ms/epoch - 38ms/step
# Epoch 209/1000
# 2/2 - 0s - loss: 32.5734 - accuracy: 0.4737 - false_negatives_6: 5.0000 - false_positives_6: 15.0000 - 65ms/epoch - 32ms/step
# Epoch 210/1000
# 2/2 - 0s - loss: 10.9240 - accuracy: 0.6842 - false_negatives_6: 0.0000e+00 - false_positives_6: 12.0000 - 68ms/epoch - 34ms/step
# Epoch 211/1000
# 2/2 - 0s - loss: 13.0512 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 66ms/epoch - 33ms/step
# Epoch 212/1000
# 2/2 - 0s - loss: 14.4579 - accuracy: 0.5526 - false_negatives_6: 17.0000 - false_positives_6: 0.0000e+00 - 74ms/epoch - 37ms/step
# Epoch 213/1000
# 2/2 - 0s - loss: 95.6319 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 80ms/epoch - 40ms/step
# Epoch 214/1000
# 2/2 - 0s - loss: 15.5858 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 65ms/epoch - 33ms/step
# Epoch 215/1000
# 2/2 - 0s - loss: 20.8546 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 80ms/epoch - 40ms/step
# Epoch 216/1000
# 2/2 - 0s - loss: 65.2740 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 64ms/epoch - 32ms/step
# Epoch 217/1000
# 2/2 - 0s - loss: 17.4998 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 68ms/epoch - 34ms/step
# Epoch 218/1000
# 2/2 - 0s - loss: 9.8468 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 70ms/epoch - 35ms/step
# Epoch 219/1000
# 2/2 - 0s - loss: 151.6094 - accuracy: 0.4474 - false_negatives_6: 6.0000 - false_positives_6: 15.0000 - 73ms/epoch - 37ms/step
# Epoch 220/1000
# 2/2 - 0s - loss: 31.0400 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 65ms/epoch - 32ms/step
# Epoch 221/1000
# 2/2 - 0s - loss: 12.8458 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 68ms/epoch - 34ms/step
# Epoch 222/1000
# 2/2 - 0s - loss: 30.0646 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 69ms/epoch - 34ms/step
# Epoch 223/1000
# 2/2 - 0s - loss: 51.5909 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 66ms/epoch - 33ms/step
# Epoch 224/1000
# 2/2 - 0s - loss: 21.9037 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 66ms/epoch - 33ms/step
# Epoch 225/1000
# 2/2 - 0s - loss: 51.6620 - accuracy: 0.3947 - false_negatives_6: 22.0000 - false_positives_6: 1.0000 - 74ms/epoch - 37ms/step
# Epoch 226/1000
# 2/2 - 0s - loss: 10.9155 - accuracy: 0.4737 - false_negatives_6: 19.0000 - false_positives_6: 1.0000 - 84ms/epoch - 42ms/step
# Epoch 227/1000
# 2/2 - 0s - loss: 14.6653 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 71ms/epoch - 36ms/step
# Epoch 228/1000
# 2/2 - 0s - loss: 13.4918 - accuracy: 0.7368 - false_negatives_6: 7.0000 - false_positives_6: 3.0000 - 78ms/epoch - 39ms/step
# Epoch 229/1000
# 2/2 - 0s - loss: 60.1557 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 62ms/epoch - 31ms/step
# Epoch 230/1000
# 2/2 - 0s - loss: 17.0471 - accuracy: 0.5789 - false_negatives_6: 14.0000 - false_positives_6: 2.0000 - 65ms/epoch - 33ms/step
# Epoch 231/1000
# 2/2 - 0s - loss: 9.8281 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 70ms/epoch - 35ms/step
# Epoch 232/1000
# 2/2 - 0s - loss: 20.6552 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 67ms/epoch - 33ms/step
# Epoch 233/1000
# 2/2 - 0s - loss: 14.8673 - accuracy: 0.9211 - false_negatives_6: 2.0000 - false_positives_6: 1.0000 - 70ms/epoch - 35ms/step
# Epoch 234/1000
# 2/2 - 0s - loss: 94.7474 - accuracy: 0.7105 - false_negatives_6: 1.0000 - false_positives_6: 10.0000 - 74ms/epoch - 37ms/step
# Epoch 235/1000
# 2/2 - 0s - loss: 65.7339 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 64ms/epoch - 32ms/step
# Epoch 236/1000
# 2/2 - 0s - loss: 80.3531 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 64ms/epoch - 32ms/step
# Epoch 237/1000
# 2/2 - 0s - loss: 16.1759 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 71ms/epoch - 35ms/step
# Epoch 238/1000
# 2/2 - 0s - loss: 38.0140 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 67ms/epoch - 33ms/step
# Epoch 239/1000
# 2/2 - 0s - loss: 12.1455 - accuracy: 0.6842 - false_negatives_6: 0.0000e+00 - false_positives_6: 12.0000 - 64ms/epoch - 32ms/step
# Epoch 240/1000
# 2/2 - 0s - loss: 21.8976 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 86ms/epoch - 43ms/step
# Epoch 241/1000
# 2/2 - 0s - loss: 35.9509 - accuracy: 0.5263 - false_negatives_6: 18.0000 - false_positives_6: 0.0000e+00 - 78ms/epoch - 39ms/step
# Epoch 242/1000
# 2/2 - 0s - loss: 14.7439 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 66ms/epoch - 33ms/step
# Epoch 243/1000
# 2/2 - 0s - loss: 29.5847 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 67ms/epoch - 34ms/step
# Epoch 244/1000
# 2/2 - 0s - loss: 29.8756 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 76ms/epoch - 38ms/step
# Epoch 245/1000
# 2/2 - 0s - loss: 41.1594 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 73ms/epoch - 37ms/step
# Epoch 246/1000
# 2/2 - 0s - loss: 19.9504 - accuracy: 0.5789 - false_negatives_6: 3.0000 - false_positives_6: 13.0000 - 66ms/epoch - 33ms/step
# Epoch 247/1000
# 2/2 - 0s - loss: 14.8622 - accuracy: 0.5526 - false_negatives_6: 8.0000 - false_positives_6: 9.0000 - 67ms/epoch - 34ms/step
# Epoch 248/1000
# 2/2 - 0s - loss: 55.3523 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 84ms/epoch - 42ms/step
# Epoch 249/1000
# 2/2 - 0s - loss: 17.6653 - accuracy: 0.5789 - false_negatives_6: 3.0000 - false_positives_6: 13.0000 - 71ms/epoch - 36ms/step
# Epoch 250/1000
# 2/2 - 0s - loss: 17.1229 - accuracy: 0.7368 - false_negatives_6: 5.0000 - false_positives_6: 5.0000 - 80ms/epoch - 40ms/step
# Epoch 251/1000
# 2/2 - 0s - loss: 26.7240 - accuracy: 0.4737 - false_negatives_6: 19.0000 - false_positives_6: 1.0000 - 71ms/epoch - 36ms/step
# Epoch 252/1000
# 2/2 - 0s - loss: 24.2718 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 80ms/epoch - 40ms/step
# Epoch 253/1000
# 2/2 - 0s - loss: 10.4811 - accuracy: 0.5263 - false_negatives_6: 3.0000 - false_positives_6: 15.0000 - 80ms/epoch - 40ms/step
# Epoch 254/1000
# 2/2 - 0s - loss: 12.6416 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 68ms/epoch - 34ms/step
# Epoch 255/1000
# 2/2 - 0s - loss: 10.6046 - accuracy: 0.7368 - false_negatives_6: 1.0000 - false_positives_6: 9.0000 - 67ms/epoch - 33ms/step
# Epoch 256/1000
# 2/2 - 0s - loss: 47.2962 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 72ms/epoch - 36ms/step
# Epoch 257/1000
# 2/2 - 0s - loss: 29.6342 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 67ms/epoch - 33ms/step
# Epoch 258/1000
# 2/2 - 0s - loss: 33.9876 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 72ms/epoch - 36ms/step
# Epoch 259/1000
# 2/2 - 0s - loss: 13.7899 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 76ms/epoch - 38ms/step
# Epoch 260/1000
# 2/2 - 0s - loss: 12.3246 - accuracy: 0.3947 - false_negatives_6: 21.0000 - false_positives_6: 2.0000 - 71ms/epoch - 36ms/step
# Epoch 261/1000
# 2/2 - 0s - loss: 48.9288 - accuracy: 0.6316 - false_negatives_6: 0.0000e+00 - false_positives_6: 14.0000 - 69ms/epoch - 34ms/step
# Epoch 262/1000
# 2/2 - 0s - loss: 19.6120 - accuracy: 0.2632 - false_negatives_6: 20.0000 - false_positives_6: 8.0000 - 76ms/epoch - 38ms/step
# Epoch 263/1000
# 2/2 - 0s - loss: 17.8668 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 82ms/epoch - 41ms/step
# Epoch 264/1000
# 2/2 - 0s - loss: 14.3435 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 68ms/epoch - 34ms/step
# Epoch 265/1000
# 2/2 - 0s - loss: 13.2577 - accuracy: 0.4474 - false_negatives_6: 7.0000 - false_positives_6: 14.0000 - 81ms/epoch - 40ms/step
# Epoch 266/1000
# 2/2 - 0s - loss: 65.5080 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 76ms/epoch - 38ms/step
# Epoch 267/1000
# 2/2 - 0s - loss: 12.5889 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 70ms/epoch - 35ms/step
# Epoch 268/1000
# 2/2 - 0s - loss: 12.8790 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 269/1000
# 2/2 - 0s - loss: 72.3560 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 75ms/epoch - 37ms/step
# Epoch 270/1000
# 2/2 - 0s - loss: 106.0740 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 69ms/epoch - 34ms/step
# Epoch 271/1000
# 2/2 - 0s - loss: 26.5716 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 67ms/epoch - 34ms/step
# Epoch 272/1000
# 2/2 - 0s - loss: 15.4822 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 68ms/epoch - 34ms/step
# Epoch 273/1000
# 2/2 - 0s - loss: 21.8823 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 65ms/epoch - 32ms/step
# Epoch 274/1000
# 2/2 - 0s - loss: 12.1004 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 72ms/epoch - 36ms/step
# Epoch 275/1000
# 2/2 - 0s - loss: 12.4223 - accuracy: 0.2895 - false_negatives_6: 15.0000 - false_positives_6: 12.0000 - 81ms/epoch - 41ms/step
# Epoch 276/1000
# 2/2 - 0s - loss: 88.4295 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 74ms/epoch - 37ms/step
# Epoch 277/1000
# 2/2 - 0s - loss: 15.9135 - accuracy: 0.4211 - false_negatives_6: 11.0000 - false_positives_6: 11.0000 - 67ms/epoch - 33ms/step
# Epoch 278/1000
# 2/2 - 0s - loss: 68.7683 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 73ms/epoch - 36ms/step
# Epoch 279/1000
# 2/2 - 0s - loss: 14.5807 - accuracy: 0.3158 - false_negatives_6: 11.0000 - false_positives_6: 15.0000 - 80ms/epoch - 40ms/step
# Epoch 280/1000
# 2/2 - 0s - loss: 30.4093 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 62ms/epoch - 31ms/step
# Epoch 281/1000
# 2/2 - 0s - loss: 149.1386 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 64ms/epoch - 32ms/step
# Epoch 282/1000
# 2/2 - 0s - loss: 12.3073 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 66ms/epoch - 33ms/step
# Epoch 283/1000
# 2/2 - 0s - loss: 22.4293 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 77ms/epoch - 39ms/step
# Epoch 284/1000
# 2/2 - 0s - loss: 16.1011 - accuracy: 0.4211 - false_negatives_6: 22.0000 - false_positives_6: 0.0000e+00 - 66ms/epoch - 33ms/step
# Epoch 285/1000
# 2/2 - 0s - loss: 13.4140 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 74ms/epoch - 37ms/step
# Epoch 286/1000
# 2/2 - 0s - loss: 11.3308 - accuracy: 0.5263 - false_negatives_6: 3.0000 - false_positives_6: 15.0000 - 71ms/epoch - 35ms/step
# Epoch 287/1000
# 2/2 - 0s - loss: 11.0217 - accuracy: 0.6842 - false_negatives_6: 0.0000e+00 - false_positives_6: 12.0000 - 67ms/epoch - 33ms/step
# Epoch 288/1000
# 2/2 - 0s - loss: 20.6435 - accuracy: 0.3158 - false_negatives_6: 22.0000 - false_positives_6: 4.0000 - 73ms/epoch - 36ms/step
# Epoch 289/1000
# 2/2 - 0s - loss: 54.9466 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 66ms/epoch - 33ms/step
# Epoch 290/1000
# 2/2 - 0s - loss: 11.7263 - accuracy: 0.3421 - false_negatives_6: 22.0000 - false_positives_6: 3.0000 - 67ms/epoch - 34ms/step
# Epoch 291/1000
# 2/2 - 0s - loss: 12.1751 - accuracy: 0.2632 - false_negatives_6: 22.0000 - false_positives_6: 6.0000 - 72ms/epoch - 36ms/step
# Epoch 292/1000
# 2/2 - 0s - loss: 14.5561 - accuracy: 0.6579 - false_negatives_6: 1.0000 - false_positives_6: 12.0000 - 84ms/epoch - 42ms/step
# Epoch 293/1000
# 2/2 - 0s - loss: 14.2532 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 65ms/epoch - 32ms/step
# Epoch 294/1000
# 2/2 - 0s - loss: 22.1850 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 71ms/epoch - 36ms/step
# Epoch 295/1000
# 2/2 - 0s - loss: 14.8382 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 65ms/epoch - 33ms/step
# Epoch 296/1000
# 2/2 - 0s - loss: 14.1329 - accuracy: 0.5789 - false_negatives_6: 9.0000 - false_positives_6: 7.0000 - 68ms/epoch - 34ms/step
# Epoch 297/1000
# 2/2 - 0s - loss: 18.8000 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 72ms/epoch - 36ms/step
# Epoch 298/1000
# 2/2 - 0s - loss: 23.3404 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 83ms/epoch - 41ms/step
# Epoch 299/1000
# 2/2 - 0s - loss: 33.2162 - accuracy: 0.5000 - false_negatives_6: 18.0000 - false_positives_6: 1.0000 - 71ms/epoch - 36ms/step
# Epoch 300/1000
# 2/2 - 0s - loss: 28.2848 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 65ms/epoch - 33ms/step
# Epoch 301/1000
# 2/2 - 0s - loss: 41.9622 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 71ms/epoch - 36ms/step
# Epoch 302/1000
# 2/2 - 0s - loss: 16.3919 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 63ms/epoch - 31ms/step
# Epoch 303/1000
# 2/2 - 0s - loss: 151.5714 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 65ms/epoch - 33ms/step
# Epoch 304/1000
# 2/2 - 0s - loss: 44.9445 - accuracy: 0.3947 - false_negatives_6: 21.0000 - false_positives_6: 2.0000 - 68ms/epoch - 34ms/step
# Epoch 305/1000
# 2/2 - 0s - loss: 26.9053 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 90ms/epoch - 45ms/step
# Epoch 306/1000
# 2/2 - 0s - loss: 28.4418 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 66ms/epoch - 33ms/step
# Epoch 307/1000
# 2/2 - 0s - loss: 11.2130 - accuracy: 0.7105 - false_negatives_6: 3.0000 - false_positives_6: 8.0000 - 67ms/epoch - 34ms/step
# Epoch 308/1000
# 2/2 - 0s - loss: 17.5760 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 63ms/epoch - 32ms/step
# Epoch 309/1000
# 2/2 - 0s - loss: 15.9765 - accuracy: 0.4211 - false_negatives_6: 19.0000 - false_positives_6: 3.0000 - 69ms/epoch - 35ms/step
# Epoch 310/1000
# 2/2 - 0s - loss: 17.1279 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 69ms/epoch - 34ms/step
# Epoch 311/1000
# 2/2 - 0s - loss: 15.5982 - accuracy: 0.3684 - false_negatives_6: 23.0000 - false_positives_6: 1.0000 - 78ms/epoch - 39ms/step
# Epoch 312/1000
# 2/2 - 0s - loss: 22.7720 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 75ms/epoch - 38ms/step
# Epoch 313/1000
# 2/2 - 0s - loss: 168.0922 - accuracy: 0.6579 - false_negatives_6: 2.0000 - false_positives_6: 11.0000 - 66ms/epoch - 33ms/step
# Epoch 314/1000
# 2/2 - 0s - loss: 18.0996 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 66ms/epoch - 33ms/step
# Epoch 315/1000
# 2/2 - 0s - loss: 26.4399 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 77ms/epoch - 39ms/step
# Epoch 316/1000
# 2/2 - 0s - loss: 47.7731 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 64ms/epoch - 32ms/step
# Epoch 317/1000
# 2/2 - 0s - loss: 16.7975 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 65ms/epoch - 33ms/step
# Epoch 318/1000
# 2/2 - 0s - loss: 12.4751 - accuracy: 0.3421 - false_negatives_6: 10.0000 - false_positives_6: 15.0000 - 73ms/epoch - 37ms/step
# Epoch 319/1000
# 2/2 - 0s - loss: 72.3037 - accuracy: 0.3684 - false_negatives_6: 23.0000 - false_positives_6: 1.0000 - 70ms/epoch - 35ms/step
# Epoch 320/1000
# 2/2 - 0s - loss: 125.2569 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 64ms/epoch - 32ms/step
# Epoch 321/1000
# 2/2 - 0s - loss: 55.5569 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 67ms/epoch - 34ms/step
# Epoch 322/1000
# 2/2 - 0s - loss: 12.6202 - accuracy: 0.7105 - false_negatives_6: 6.0000 - false_positives_6: 5.0000 - 115ms/epoch - 57ms/step
# Epoch 323/1000
# 2/2 - 0s - loss: 15.2549 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 119ms/epoch - 60ms/step
# Epoch 324/1000
# 2/2 - 0s - loss: 26.3933 - accuracy: 0.6842 - false_negatives_6: 0.0000e+00 - false_positives_6: 12.0000 - 133ms/epoch - 66ms/step
# Epoch 325/1000
# 2/2 - 0s - loss: 59.2678 - accuracy: 0.2895 - false_negatives_6: 20.0000 - false_positives_6: 7.0000 - 149ms/epoch - 74ms/step
# Epoch 326/1000
# 2/2 - 0s - loss: 18.5706 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 265ms/epoch - 133ms/step
# Epoch 327/1000
# 2/2 - 0s - loss: 37.2241 - accuracy: 0.3158 - false_negatives_6: 22.0000 - false_positives_6: 4.0000 - 191ms/epoch - 95ms/step
# Epoch 328/1000
# 2/2 - 0s - loss: 19.7467 - accuracy: 0.5263 - false_negatives_6: 5.0000 - false_positives_6: 13.0000 - 145ms/epoch - 73ms/step
# Epoch 329/1000
# 2/2 - 0s - loss: 14.6560 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 144ms/epoch - 72ms/step
# Epoch 330/1000
# 2/2 - 0s - loss: 30.5405 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 123ms/epoch - 62ms/step
# Epoch 331/1000
# 2/2 - 0s - loss: 12.4481 - accuracy: 0.7632 - false_negatives_6: 1.0000 - false_positives_6: 8.0000 - 131ms/epoch - 65ms/step
# Epoch 332/1000
# 2/2 - 0s - loss: 27.2087 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 129ms/epoch - 65ms/step
# Epoch 333/1000
# 2/2 - 0s - loss: 12.0790 - accuracy: 0.4737 - false_negatives_6: 5.0000 - false_positives_6: 15.0000 - 132ms/epoch - 66ms/step
# Epoch 334/1000
# 2/2 - 0s - loss: 38.9903 - accuracy: 0.7105 - false_negatives_6: 2.0000 - false_positives_6: 9.0000 - 138ms/epoch - 69ms/step
# Epoch 335/1000
# 2/2 - 0s - loss: 56.5408 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 129ms/epoch - 65ms/step
# Epoch 336/1000
# 2/2 - 0s - loss: 20.2741 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 131ms/epoch - 66ms/step
# Epoch 337/1000
# 2/2 - 0s - loss: 16.8568 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 128ms/epoch - 64ms/step
# ...
# Epoch 892/1000
# 2/2 - 0s - loss: 31.0673 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 74ms/epoch - 37ms/step
# Epoch 893/1000
# 2/2 - 0s - loss: 33.3871 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 84ms/epoch - 42ms/step
# Epoch 894/1000
# 2/2 - 0s - loss: 37.8285 - accuracy: 0.3684 - false_negatives_6: 23.0000 - false_positives_6: 1.0000 - 71ms/epoch - 36ms/step
# Epoch 895/1000
# 2/2 - 0s - loss: 65.1198 - accuracy: 0.4211 - false_negatives_6: 20.0000 - false_positives_6: 2.0000 - 84ms/epoch - 42ms/step
# Epoch 896/1000
# 2/2 - 0s - loss: 17.8141 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 70ms/epoch - 35ms/step
# Epoch 897/1000
# 2/2 - 0s - loss: 124.0040 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 70ms/epoch - 35ms/step
# Epoch 898/1000
# 2/2 - 0s - loss: 19.2129 - accuracy: 0.2632 - false_negatives_6: 17.0000 - false_positives_6: 11.0000 - 71ms/epoch - 35ms/step
# Epoch 899/1000
# 2/2 - 0s - loss: 18.6507 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 68ms/epoch - 34ms/step
# Epoch 900/1000
# 2/2 - 0s - loss: 57.0441 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 68ms/epoch - 34ms/step
# Epoch 901/1000
# 2/2 - 0s - loss: 19.7138 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 77ms/epoch - 38ms/step
# Epoch 902/1000
# 2/2 - 0s - loss: 19.4192 - accuracy: 0.6842 - false_negatives_6: 1.0000 - false_positives_6: 11.0000 - 71ms/epoch - 35ms/step
# Epoch 903/1000
# 2/2 - 0s - loss: 17.2820 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 75ms/epoch - 38ms/step
# Epoch 904/1000
# 2/2 - 0s - loss: 32.4817 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 80ms/epoch - 40ms/step
# Epoch 905/1000
# 2/2 - 0s - loss: 17.0946 - accuracy: 0.5789 - false_negatives_6: 3.0000 - false_positives_6: 13.0000 - 82ms/epoch - 41ms/step
# Epoch 906/1000
# 2/2 - 0s - loss: 17.5256 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 77ms/epoch - 38ms/step
# Epoch 907/1000
# 2/2 - 0s - loss: 18.0671 - accuracy: 0.6053 - false_negatives_6: 10.0000 - false_positives_6: 5.0000 - 81ms/epoch - 40ms/step
# Epoch 908/1000
# 2/2 - 0s - loss: 17.9997 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 71ms/epoch - 36ms/step
# Epoch 909/1000
# 2/2 - 0s - loss: 25.8432 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 68ms/epoch - 34ms/step
# Epoch 910/1000
# 2/2 - 0s - loss: 28.3260 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 80ms/epoch - 40ms/step
# Epoch 911/1000
# 2/2 - 0s - loss: 19.8772 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 69ms/epoch - 34ms/step
# Epoch 912/1000
# 2/2 - 0s - loss: 36.7316 - accuracy: 0.5789 - false_negatives_6: 1.0000 - false_positives_6: 15.0000 - 70ms/epoch - 35ms/step
# Epoch 913/1000
# 2/2 - 0s - loss: 30.7706 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 76ms/epoch - 38ms/step
# Epoch 914/1000
# 2/2 - 0s - loss: 82.2099 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 70ms/epoch - 35ms/step
# Epoch 915/1000
# 2/2 - 0s - loss: 19.5230 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 75ms/epoch - 37ms/step
# Epoch 916/1000
# 2/2 - 0s - loss: 18.6550 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 80ms/epoch - 40ms/step
# Epoch 917/1000
# 2/2 - 0s - loss: 15.5104 - accuracy: 0.3947 - false_negatives_6: 15.0000 - false_positives_6: 8.0000 - 70ms/epoch - 35ms/step
# Epoch 918/1000
# 2/2 - 0s - loss: 34.2509 - accuracy: 0.5526 - false_negatives_6: 13.0000 - false_positives_6: 4.0000 - 82ms/epoch - 41ms/step
# Epoch 919/1000
# 2/2 - 0s - loss: 20.2193 - accuracy: 0.7895 - false_negatives_6: 4.0000 - false_positives_6: 4.0000 - 85ms/epoch - 42ms/step
# Epoch 920/1000
# 2/2 - 0s - loss: 25.0051 - accuracy: 0.3158 - false_negatives_6: 19.0000 - false_positives_6: 7.0000 - 69ms/epoch - 34ms/step
# Epoch 921/1000
# 2/2 - 0s - loss: 17.8101 - accuracy: 0.6316 - false_negatives_6: 0.0000e+00 - false_positives_6: 14.0000 - 67ms/epoch - 34ms/step
# Epoch 922/1000
# 2/2 - 0s - loss: 20.1007 - accuracy: 0.6316 - false_negatives_6: 2.0000 - false_positives_6: 12.0000 - 77ms/epoch - 38ms/step
# Epoch 923/1000
# 2/2 - 0s - loss: 21.5400 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 71ms/epoch - 35ms/step
# Epoch 924/1000
# 2/2 - 0s - loss: 29.9879 - accuracy: 0.2368 - false_negatives_6: 20.0000 - false_positives_6: 9.0000 - 67ms/epoch - 34ms/step
# Epoch 925/1000
# 2/2 - 0s - loss: 24.8502 - accuracy: 0.6316 - false_negatives_6: 4.0000 - false_positives_6: 10.0000 - 74ms/epoch - 37ms/step
# Epoch 926/1000
# 2/2 - 0s - loss: 17.7831 - accuracy: 0.5263 - false_negatives_6: 3.0000 - false_positives_6: 15.0000 - 72ms/epoch - 36ms/step
# Epoch 927/1000
# 2/2 - 0s - loss: 41.8001 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 79ms/epoch - 39ms/step
# Epoch 928/1000
# 2/2 - 0s - loss: 17.7518 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 72ms/epoch - 36ms/step
# Epoch 929/1000
# 2/2 - 0s - loss: 38.6367 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 76ms/epoch - 38ms/step
# Epoch 930/1000
# 2/2 - 0s - loss: 22.8900 - accuracy: 0.6579 - false_negatives_6: 0.0000e+00 - false_positives_6: 13.0000 - 69ms/epoch - 34ms/step
# Epoch 931/1000
# 2/2 - 0s - loss: 85.0096 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 79ms/epoch - 39ms/step
# Epoch 932/1000
# 2/2 - 0s - loss: 18.1806 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 81ms/epoch - 40ms/step
# Epoch 933/1000
# 2/2 - 0s - loss: 26.4878 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 74ms/epoch - 37ms/step
# Epoch 934/1000
# 2/2 - 0s - loss: 16.7942 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 71ms/epoch - 36ms/step
# Epoch 935/1000
# 2/2 - 0s - loss: 25.1737 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 74ms/epoch - 37ms/step
# Epoch 936/1000
# 2/2 - 0s - loss: 121.1451 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 80ms/epoch - 40ms/step
# Epoch 937/1000
# 2/2 - 0s - loss: 17.7859 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 74ms/epoch - 37ms/step
# Epoch 938/1000
# 2/2 - 0s - loss: 29.7246 - accuracy: 0.5000 - false_negatives_6: 5.0000 - false_positives_6: 14.0000 - 79ms/epoch - 39ms/step
# Epoch 939/1000
# 2/2 - 0s - loss: 25.7466 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 73ms/epoch - 36ms/step
# Epoch 940/1000
# 2/2 - 0s - loss: 27.5194 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 66ms/epoch - 33ms/step
# Epoch 941/1000
# 2/2 - 0s - loss: 19.4088 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 74ms/epoch - 37ms/step
# Epoch 942/1000
# 2/2 - 0s - loss: 164.6499 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 74ms/epoch - 37ms/step
# Epoch 943/1000
# 2/2 - 0s - loss: 22.4440 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 79ms/epoch - 39ms/step
# Epoch 944/1000
# 2/2 - 0s - loss: 35.1459 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 88ms/epoch - 44ms/step
# Epoch 945/1000
# 2/2 - 0s - loss: 20.3797 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 67ms/epoch - 33ms/step
# Epoch 946/1000
# 2/2 - 0s - loss: 17.8450 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 68ms/epoch - 34ms/step
# Epoch 947/1000
# 2/2 - 0s - loss: 17.4574 - accuracy: 0.7895 - false_negatives_6: 4.0000 - false_positives_6: 4.0000 - 78ms/epoch - 39ms/step
# Epoch 948/1000
# 2/2 - 0s - loss: 16.8149 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 64ms/epoch - 32ms/step
# Epoch 949/1000
# 2/2 - 0s - loss: 173.7655 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 69ms/epoch - 35ms/step
# Epoch 950/1000
# 2/2 - 0s - loss: 47.2916 - accuracy: 0.6053 - false_negatives_6: 2.0000 - false_positives_6: 13.0000 - 67ms/epoch - 33ms/step
# Epoch 951/1000
# 2/2 - 0s - loss: 117.9752 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 78ms/epoch - 39ms/step
# Epoch 952/1000
# 2/2 - 0s - loss: 19.1870 - accuracy: 0.3684 - false_negatives_6: 18.0000 - false_positives_6: 6.0000 - 72ms/epoch - 36ms/step
# Epoch 953/1000
# 2/2 - 0s - loss: 25.5657 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 70ms/epoch - 35ms/step
# Epoch 954/1000
# 2/2 - 0s - loss: 23.9159 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 77ms/epoch - 39ms/step
# Epoch 955/1000
# 2/2 - 0s - loss: 28.3259 - accuracy: 0.2632 - false_negatives_6: 21.0000 - false_positives_6: 7.0000 - 71ms/epoch - 35ms/step
# Epoch 956/1000
# 2/2 - 0s - loss: 17.0835 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 107ms/epoch - 53ms/step
# Epoch 957/1000
# 2/2 - 0s - loss: 22.6393 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 74ms/epoch - 37ms/step
# Epoch 958/1000
# 2/2 - 0s - loss: 17.1733 - accuracy: 0.4474 - false_negatives_6: 20.0000 - false_positives_6: 1.0000 - 73ms/epoch - 37ms/step
# Epoch 959/1000
# 2/2 - 0s - loss: 23.7790 - accuracy: 0.2368 - false_negatives_6: 23.0000 - false_positives_6: 6.0000 - 74ms/epoch - 37ms/step
# Epoch 960/1000
# 2/2 - 0s - loss: 16.8544 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 74ms/epoch - 37ms/step
# Epoch 961/1000
# 2/2 - 0s - loss: 51.5246 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 89ms/epoch - 44ms/step
# Epoch 962/1000
# 2/2 - 0s - loss: 25.5259 - accuracy: 0.6316 - false_negatives_6: 0.0000e+00 - false_positives_6: 14.0000 - 68ms/epoch - 34ms/step
# Epoch 963/1000
# 2/2 - 0s - loss: 19.3586 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 68ms/epoch - 34ms/step
# Epoch 964/1000
# 2/2 - 0s - loss: 19.6122 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 73ms/epoch - 37ms/step
# Epoch 965/1000
# 2/2 - 0s - loss: 21.1608 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 93ms/epoch - 46ms/step
# Epoch 966/1000
# 2/2 - 0s - loss: 19.7193 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 131ms/epoch - 66ms/step
# Epoch 967/1000
# 2/2 - 0s - loss: 36.1326 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 135ms/epoch - 67ms/step
# Epoch 968/1000
# 2/2 - 0s - loss: 36.1575 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 131ms/epoch - 66ms/step
# Epoch 969/1000
# 2/2 - 0s - loss: 21.0992 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 113ms/epoch - 57ms/step
# Epoch 970/1000
# 2/2 - 0s - loss: 25.9627 - accuracy: 0.2105 - false_negatives_6: 19.0000 - false_positives_6: 11.0000 - 149ms/epoch - 74ms/step
# Epoch 971/1000
# 2/2 - 0s - loss: 16.4812 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 136ms/epoch - 68ms/step
# Epoch 972/1000
# 2/2 - 0s - loss: 27.7324 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 139ms/epoch - 70ms/step
# Epoch 973/1000
# 2/2 - 0s - loss: 18.2769 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 133ms/epoch - 67ms/step
# Epoch 974/1000
# 2/2 - 0s - loss: 110.0842 - accuracy: 0.4211 - false_negatives_6: 22.0000 - false_positives_6: 0.0000e+00 - 132ms/epoch - 66ms/step
# Epoch 975/1000
# 2/2 - 0s - loss: 17.1650 - accuracy: 0.5526 - false_negatives_6: 4.0000 - false_positives_6: 13.0000 - 139ms/epoch - 70ms/step
# Epoch 976/1000
# 2/2 - 0s - loss: 28.4486 - accuracy: 0.6316 - false_negatives_6: 0.0000e+00 - false_positives_6: 14.0000 - 130ms/epoch - 65ms/step
# Epoch 977/1000
# 2/2 - 0s - loss: 41.4347 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 124ms/epoch - 62ms/step
# Epoch 978/1000
# 2/2 - 0s - loss: 18.4454 - accuracy: 0.4737 - false_negatives_6: 19.0000 - false_positives_6: 1.0000 - 126ms/epoch - 63ms/step
# Epoch 979/1000
# 2/2 - 0s - loss: 33.4222 - accuracy: 0.5526 - false_negatives_6: 5.0000 - false_positives_6: 12.0000 - 126ms/epoch - 63ms/step
# Epoch 980/1000
# 2/2 - 0s - loss: 37.3968 - accuracy: 0.4474 - false_negatives_6: 21.0000 - false_positives_6: 0.0000e+00 - 124ms/epoch - 62ms/step
# Epoch 981/1000
# 2/2 - 0s - loss: 33.2212 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 123ms/epoch - 61ms/step
# Epoch 982/1000
# 2/2 - 0s - loss: 21.1558 - accuracy: 0.6053 - false_negatives_6: 3.0000 - false_positives_6: 12.0000 - 124ms/epoch - 62ms/step
# Epoch 983/1000
# 2/2 - 0s - loss: 17.2507 - accuracy: 0.6316 - false_negatives_6: 0.0000e+00 - false_positives_6: 14.0000 - 141ms/epoch - 71ms/step
# Epoch 984/1000
# 2/2 - 0s - loss: 59.7380 - accuracy: 0.3947 - false_negatives_6: 20.0000 - false_positives_6: 3.0000 - 139ms/epoch - 69ms/step
# Epoch 985/1000
# 2/2 - 0s - loss: 18.3196 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 129ms/epoch - 65ms/step
# Epoch 986/1000
# 2/2 - 0s - loss: 18.9085 - accuracy: 0.6316 - false_negatives_6: 2.0000 - false_positives_6: 12.0000 - 134ms/epoch - 67ms/step
# Epoch 987/1000
# 2/2 - 0s - loss: 24.4958 - accuracy: 0.3947 - false_negatives_6: 23.0000 - false_positives_6: 0.0000e+00 - 134ms/epoch - 67ms/step
# Epoch 988/1000
# 2/2 - 0s - loss: 34.1964 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 136ms/epoch - 68ms/step
# Epoch 989/1000
# 2/2 - 0s - loss: 17.6285 - accuracy: 0.7632 - false_negatives_6: 6.0000 - false_positives_6: 3.0000 - 132ms/epoch - 66ms/step
# Epoch 990/1000
# 2/2 - 0s - loss: 24.2194 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 130ms/epoch - 65ms/step
# Epoch 991/1000
# 2/2 - 0s - loss: 18.7103 - accuracy: 0.4474 - false_negatives_6: 19.0000 - false_positives_6: 2.0000 - 137ms/epoch - 68ms/step
# Epoch 992/1000
# 2/2 - 0s - loss: 17.8037 - accuracy: 0.8158 - false_negatives_6: 2.0000 - false_positives_6: 5.0000 - 128ms/epoch - 64ms/step
# Epoch 993/1000
# 2/2 - 0s - loss: 37.2597 - accuracy: 0.7105 - false_negatives_6: 5.0000 - false_positives_6: 6.0000 - 131ms/epoch - 65ms/step
# Epoch 994/1000
# 2/2 - 0s - loss: 20.3963 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 129ms/epoch - 64ms/step
# Epoch 995/1000
# 2/2 - 0s - loss: 19.3895 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 127ms/epoch - 64ms/step
# Epoch 996/1000
# 2/2 - 0s - loss: 22.6031 - accuracy: 0.6053 - false_negatives_6: 0.0000e+00 - false_positives_6: 15.0000 - 124ms/epoch - 62ms/step
# Epoch 997/1000
# 2/2 - 0s - loss: 26.3610 - accuracy: 0.3421 - false_negatives_6: 21.0000 - false_positives_6: 4.0000 - 128ms/epoch - 64ms/step
# Epoch 998/1000
# 2/2 - 0s - loss: 20.8042 - accuracy: 0.4211 - false_negatives_6: 22.0000 - false_positives_6: 0.0000e+00 - 142ms/epoch - 71ms/step
# Epoch 999/1000
# 2/2 - 0s - loss: 18.7979 - accuracy: 0.5000 - false_negatives_6: 16.0000 - false_positives_6: 3.0000 - 134ms/epoch - 67ms/step
# Epoch 1000/1000
# 2/2 - 0s - loss: 49.3655 - accuracy: 0.6579 - false_negatives_6: 0.0000e+00 - false_positives_6: 13.0000 - 124ms/epoch - 62ms/step
# 1/1 [==============================] - 3s 3s/step - loss: 67.2578 - accuracy: 0.5882 - false_negatives_6: 0.0000e+00 - false_positives_6: 7.0000
# Test Loss: 67.2578
# Test Accuracy: 58.82%
# False Negatives: 0
# False Positives: 7
# 1/1 [==============================] - 3s 3s/step
# Confusion Matrix:
# [[ 0  7]
#  [ 0 10]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of samples for uncertainty estimation
n_samples = 100
predictions = []

# Generate multiple samples from the posterior distribution
for _ in range(n_samples):
    predictions.append(model.predict(x_test))

# Convert predictions to a NumPy array
predictions = np.array(predictions)

# Calculate the predictive mean and standard deviation
mean_prediction = np.mean(predictions, axis=0).flatten()
std_prediction = np.std(predictions, axis=0).flatten()

# Create x-axis values
x_values = np.arange(1, len(mean_prediction) + 1)

# Plot uncertainty using error bars
plt.figure(figsize=(12, 6))
plt.errorbar(x_values, mean_prediction, yerr=2 * std_prediction, fmt='o', label='Predictive Mean')
plt.xlabel('Sample Index')
plt.ylabel('Predicted Value')
plt.xticks(x_values)  # Set the x-axis ticks to the specific numbers
plt.title('Variational Inference Predictive Mean and Uncertainty (2 std)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
