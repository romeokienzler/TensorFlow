# %%
# !pip install tensorflow==2.0.0-alpha0 
#!pip install tensorflow==1.3.0
# Out:
# Collecting tensorflow==2.0.0-alpha0
#   Downloading https://files.pythonhosted.org/packages/92/7a/8d374bf3de51551e1d049ebf42cbeb677ac7f4c4089f036dd1834a283c52/tensorflow-2.0.0a0-cp35-cp35m-manylinux1_x86_64.whl (79.9MB)
#     100% |████████████████████████████████| 79.9MB 12kB/s  eta 0:00:01
# Collecting keras-preprocessing>=1.0.5 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/c0/bf/0315ef6a9fd3fc2346e85b0ff1f5f83ca17073f2c31ac719ab2e4da0d4a3/Keras_Preprocessing-1.0.9-py2.py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 9.0MB/s eta 0:00:01
# Collecting gast>=0.2.0 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting numpy<2.0,>=1.14.5 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/f6/f3/cc6c6745347c1e997cc3e58390584a250b8e22b6dfc45414a7d69a3df016/numpy-1.16.3-cp35-cp35m-manylinux1_x86_64.whl (17.2MB)
#     100% |████████████████████████████████| 17.2MB 53kB/s  eta 0:00:01   17% |█████▌                          | 2.9MB 60.5MB/s eta 0:00:01
# Collecting protobuf>=3.6.1 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/81/59/c7b0815a78fd641141f24a6ece878293eae6bf1fce40632a6ab9672346aa/protobuf-3.7.1-cp35-cp35m-manylinux1_x86_64.whl (1.2MB)
#     100% |████████████████████████████████| 1.2MB 813kB/s eta 0:00:01
# Collecting termcolor>=1.1.0 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting tb-nightly<1.14.0a20190302,>=1.14.0a20190301 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/a9/51/aa1d756644bf4624c03844115e4ac4058eff77acd786b26315f051a4b195/tb_nightly-1.14.0a20190301-py3-none-any.whl (3.0MB)
#     100% |████████████████████████████████| 3.0MB 327kB/s eta 0:00:01  1% |▍                               | 40kB 38.0MB/s eta 0:00:01
# Requirement not upgraded as not directly required: wheel>=0.26 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from tensorflow==2.0.0-alpha0)
# Collecting google-pasta>=0.1.2 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/64/bb/f1bbc131d6294baa6085a222d29abadd012696b73dcbf8cf1bf56b9f082a/google_pasta-0.1.5-py3-none-any.whl (51kB)
#     100% |████████████████████████████████| 61kB 10.2MB/s ta 0:00:01
# Collecting absl-py>=0.7.0 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/da/3f/9b0355080b81b15ba6a9ffcf1f5ea39e307a2778b2f2dc8694724e8abd5b/absl-py-0.7.1.tar.gz (99kB)
#     100% |████████████████████████████████| 102kB 9.1MB/s ta 0:00:01
# Collecting keras-applications>=1.0.6 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/90/85/64c82949765cfb246bbdaf5aca2d55f400f792655927a017710a78445def/Keras_Applications-1.0.7-py2.py3-none-any.whl (51kB)
#     100% |████████████████████████████████| 61kB 10.2MB/s ta 0:00:01
# Requirement not upgraded as not directly required: six>=1.10.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from tensorflow==2.0.0-alpha0)
# Collecting tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/13/82/f16063b4eed210dc2ab057930ac1da4fbe1e91b7b051a6c8370b401e6ae7/tf_estimator_nightly-1.14.0.dev2019030115-py2.py3-none-any.whl (411kB)
#     100% |████████████████████████████████| 419kB 2.5MB/s eta 0:00:01
# Collecting astor>=0.6.0 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/35/6b/11530768cac581a12952a2aad00e1526b89d242d0b9f59534ef6e6a1752f/astor-0.7.1-py2.py3-none-any.whl
# Collecting grpcio>=1.8.6 (from tensorflow==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/fb/a3/d5ccc8624ed7adce45c3297ab910cdf3c457a54e61eb231246b66ef18bc1/grpcio-1.20.0-cp35-cp35m-manylinux1_x86_64.whl (2.1MB)
#     100% |████████████████████████████████| 2.1MB 418kB/s eta 0:00:01
# Requirement not upgraded as not directly required: setuptools in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from protobuf>=3.6.1->tensorflow==2.0.0-alpha0)
# Requirement not upgraded as not directly required: markdown>=2.6.8 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0-alpha0)
# Requirement not upgraded as not directly required: werkzeug>=0.11.15 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0-alpha0)
# Requirement not upgraded as not directly required: h5py in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from keras-applications>=1.0.6->tensorflow==2.0.0-alpha0)
# Building wheels for collected packages: gast, termcolor, absl-py
#   Running setup.py bdist_wheel for gast ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Running setup.py bdist_wheel for termcolor ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Running setup.py bdist_wheel for absl-py ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/ee/98/38/46cbcc5a93cfea5492d19c38562691ddb23b940176c14f7b48
# Successfully built gast termcolor absl-py
# Installing collected packages: numpy, keras-preprocessing, gast, protobuf, termcolor, absl-py, grpcio, tb-nightly, google-pasta, keras-applications, tf-estimator-nightly, astor, tensorflow
#   Found existing installation: numpy 1.13.3
#     Uninstalling numpy-1.13.3:
#       Successfully uninstalled numpy-1.13.3
#   Found existing installation: protobuf 3.4.1
#     Uninstalling protobuf-3.4.1:
#       Successfully uninstalled protobuf-3.4.1
#   Found existing installation: tensorflow 1.3.0
#     Uninstalling tensorflow-1.3.0:
#       Successfully uninstalled tensorflow-1.3.0
# Successfully installed absl-py-0.7.1 astor-0.7.1 gast-0.2.2 google-pasta-0.1.5 grpcio-1.20.0 keras-applications-1.0.7 keras-preprocessing-1.0.9 numpy-1.16.3 protobuf-3.7.1 tb-nightly-1.14.0a20190301 tensorflow-2.0.0a0 termcolor-1.1.0 tf-estimator-nightly-1.14.0.dev2019030115

# %%
import tensorflow as tf
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tf.__version__
# Out:
# '2.0.0-alpha0'

# %%
import numpy as np

# %%
a = tf.constant(np.array([1., 2., 3.]))
print(type(a))
print(a.numpy())
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# [1. 2. 3.]

# %%
b = tf.constant(np.array([4.,5.,6.]))
print(type(b))
print(b.numpy())
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# [4. 5. 6.]

# %%
c = tf.tensordot(a, b,1)
type(c)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
print(c.numpy())
# Out:
# 32.0

# %%
#session = tf.Session()
#output = session.run(c)
#print(output)
