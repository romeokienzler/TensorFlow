# %% [markdown]
# Credits / Inspired by => https://github.com/mwitiderrick/stockprice

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !pip install mido
# Out:
# Collecting mido
#   Downloading mido-1.2.9-py2.py3-none-any.whl (52 kB)
# Installing collected packages: mido
# Successfully installed mido-1.2.9

# %%
import mido
mid = mido.MidiFile('bach.mid')

# %%
song = []
full_song_message = []
for i, track in enumerate(mid.tracks):
    if track.name == "Track 1":
        for msg in track:
            print(msg)
            if msg.dict()['type'] in ['note_on','note_off']:
                song.append((msg.dict()['note'],msg.dict()['velocity'],msg.dict()['time'],msg.dict()['type']))
            full_song_message.append(msg)
# Out:
# <meta message track_name name='Track 1' time=0>
# program_change channel=0 program=19 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=192
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=79 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_off channel=0 note=74 velocity=64 time=0
# note_off channel=0 note=79 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=72 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=48
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=48
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=48
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=48
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=48
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=48
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=48
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=48
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=79 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_off channel=0 note=74 velocity=64 time=0
# note_off channel=0 note=79 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=59 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_off channel=0 note=59 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=59 velocity=92 time=0
# note_off channel=0 note=59 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=192
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=192
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=192
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_off channel=0 note=71 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=79 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_off channel=0 note=74 velocity=64 time=0
# note_off channel=0 note=79 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=72 velocity=64 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_on channel=0 note=77 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_off channel=0 note=74 velocity=64 time=0
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=96
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=192
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=192
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=192
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=192
# note_off channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=192
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=384
# note_off channel=0 note=66 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=192
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=192
# note_off channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=59 velocity=92 time=0
# note_off channel=0 note=59 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=59 velocity=92 time=0
# note_off channel=0 note=59 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=57 velocity=92 time=0
# note_off channel=0 note=57 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=59 velocity=92 time=0
# note_off channel=0 note=59 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=768
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=768
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=192
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=192
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=192
# note_off channel=0 note=62 velocity=64 time=0
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=59 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_off channel=0 note=62 velocity=64 time=0
# note_off channel=0 note=59 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=192
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=192
# note_off channel=0 note=66 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=192
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=192
# note_off channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=192
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=192
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=66 velocity=64 time=0
# note_off channel=0 note=69 velocity=64 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=68 velocity=92 time=0
# note_off channel=0 note=68 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=192
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=192
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_off channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=192
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=192
# note_off channel=0 note=71 velocity=64 time=0
# note_off channel=0 note=76 velocity=64 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_off channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=68 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=384
# note_off channel=0 note=68 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=192
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=192
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=76 velocity=64 time=0
# note_on channel=0 note=77 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=96
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=77 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=672
# note_on channel=0 note=72 velocity=92 time=96
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_off channel=0 note=76 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=672
# note_on channel=0 note=71 velocity=92 time=96
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=68 velocity=92 time=0
# note_off channel=0 note=68 velocity=64 time=96
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=72 velocity=92 time=672
# note_on channel=0 note=69 velocity=92 time=96
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=768
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=59 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=59 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=96
# note_off channel=0 note=69 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_on channel=0 note=75 velocity=92 time=0
# note_off channel=0 note=75 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_off channel=0 note=66 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_on channel=0 note=75 velocity=92 time=0
# note_off channel=0 note=75 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_off channel=0 note=71 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_off channel=0 note=76 velocity=64 time=0
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=78 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=192
# note_on channel=0 note=83 velocity=92 time=0
# note_off channel=0 note=83 velocity=64 time=192
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_on channel=0 note=83 velocity=92 time=0
# note_on channel=0 note=78 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_off channel=0 note=78 velocity=64 time=0
# note_off channel=0 note=83 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_off channel=0 note=76 velocity=64 time=0
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=81 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_on channel=0 note=83 velocity=92 time=0
# note_off channel=0 note=83 velocity=64 time=192
# note_on channel=0 note=81 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_off channel=0 note=76 velocity=64 time=0
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=75 velocity=92 time=0
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=384
# note_off channel=0 note=75 velocity=64 time=0
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_on channel=0 note=83 velocity=92 time=0
# note_on channel=0 note=78 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=192
# note_off channel=0 note=78 velocity=64 time=0
# note_off channel=0 note=83 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_off channel=0 note=76 velocity=64 time=0
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=76 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=76 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=76 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_off channel=0 note=76 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=69 velocity=64 time=0
# note_on channel=0 note=81 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=81 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=81 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=81 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=96
# note_on channel=0 note=66 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_off channel=0 note=66 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_off channel=0 note=66 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_off channel=0 note=69 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_off channel=0 note=66 velocity=64 time=96
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_off channel=0 note=66 velocity=64 time=0
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=96
# note_on channel=0 note=73 velocity=92 time=0
# note_off channel=0 note=73 velocity=64 time=96
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=78 velocity=64 time=96
# note_on channel=0 note=75 velocity=92 time=0
# note_off channel=0 note=75 velocity=64 time=96
# note_on channel=0 note=63 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=63 velocity=64 time=0
# note_on channel=0 note=61 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_off channel=0 note=61 velocity=64 time=0
# note_on channel=0 note=63 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=63 velocity=64 time=0
# note_on channel=0 note=66 velocity=92 time=0
# note_on channel=0 note=59 velocity=92 time=0
# note_off channel=0 note=59 velocity=64 time=96
# note_off channel=0 note=66 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=63 velocity=92 time=0
# note_off channel=0 note=63 velocity=64 time=96
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=61 velocity=92 time=0
# note_off channel=0 note=61 velocity=64 time=96
# note_off channel=0 note=69 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=63 velocity=92 time=0
# note_off channel=0 note=63 velocity=64 time=96
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=192
# note_off channel=0 note=72 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_on channel=0 note=75 velocity=92 time=0
# note_off channel=0 note=75 velocity=64 time=192
# note_off channel=0 note=71 velocity=64 time=0
# note_off channel=0 note=69 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_off channel=0 note=71 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# ...
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=192
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=192
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=79 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_off channel=0 note=74 velocity=64 time=0
# note_off channel=0 note=79 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=192
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_on channel=0 note=77 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=384
# note_off channel=0 note=71 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=192
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=59 velocity=92 time=0
# note_off channel=0 note=59 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_off channel=0 note=60 velocity=64 time=96
# note_on channel=0 note=62 velocity=92 time=0
# note_off channel=0 note=62 velocity=64 time=96
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=64 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_off channel=0 note=69 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=96
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_off channel=0 note=71 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_on channel=0 note=76 velocity=92 time=0
# note_off channel=0 note=76 velocity=64 time=96
# note_on channel=0 note=84 velocity=92 time=0
# note_off channel=0 note=84 velocity=64 time=96
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=83 velocity=92 time=0
# note_off channel=0 note=83 velocity=64 time=96
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=84 velocity=92 time=0
# note_off channel=0 note=84 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=84 velocity=92 time=0
# note_off channel=0 note=84 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=83 velocity=92 time=0
# note_off channel=0 note=83 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=60 velocity=92 time=0
# note_on channel=0 note=84 velocity=92 time=0
# note_off channel=0 note=84 velocity=64 time=96
# note_off channel=0 note=60 velocity=64 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=81 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=84 velocity=92 time=0
# note_off channel=0 note=84 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=83 velocity=92 time=0
# note_off channel=0 note=83 velocity=64 time=96
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=84 velocity=92 time=0
# note_off channel=0 note=84 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_off channel=0 note=74 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=69 velocity=92 time=0
# note_on channel=0 note=83 velocity=92 time=0
# note_off channel=0 note=83 velocity=64 time=96
# note_off channel=0 note=69 velocity=64 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=81 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_off channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=83 velocity=92 time=0
# note_off channel=0 note=83 velocity=64 time=96
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=84 velocity=92 time=0
# note_off channel=0 note=84 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=62 velocity=92 time=0
# note_on channel=0 note=81 velocity=92 time=0
# note_off channel=0 note=81 velocity=64 time=96
# note_off channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=79 velocity=92 time=0
# note_off channel=0 note=79 velocity=64 time=96
# note_off channel=0 note=64 velocity=64 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_on channel=0 note=77 velocity=92 time=0
# note_off channel=0 note=77 velocity=64 time=96
# note_off channel=0 note=65 velocity=64 time=0
# note_on channel=0 note=76 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_off channel=0 note=67 velocity=64 time=192
# note_off channel=0 note=72 velocity=64 time=0
# note_off channel=0 note=76 velocity=64 time=0
# note_on channel=0 note=74 velocity=92 time=0
# note_on channel=0 note=71 velocity=92 time=0
# note_on channel=0 note=65 velocity=92 time=0
# note_off channel=0 note=65 velocity=64 time=192
# note_off channel=0 note=71 velocity=64 time=0
# note_off channel=0 note=74 velocity=64 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_on channel=0 note=67 velocity=92 time=0
# note_on channel=0 note=72 velocity=92 time=0
# note_off channel=0 note=72 velocity=64 time=384
# note_off channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=0
# <meta message end_of_track time=1152>

# %%
song
# Out:
# [(67, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 192, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 192, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 192, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 192, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 192, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (74, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (79, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 192, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 192, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 48, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 48, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 48, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 48, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 48, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 48, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 48, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 48, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (74, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (79, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (65, 92, 0, 'note_on'),
#  (65, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (60, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (65, 92, 0, 'note_on'),
#  (65, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (65, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (65, 64, 0, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (65, 92, 0, 'note_on'),
#  (65, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (60, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (65, 92, 0, 'note_on'),
#  (65, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (59, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (59, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (65, 92, 0, 'note_on'),
#  (65, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (60, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (65, 92, 0, 'note_on'),
#  (65, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (65, 92, 0, 'note_on'),
#  (65, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (59, 92, 0, 'note_on'),
#  (59, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 192, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (65, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 192, 'note_off'),
#  (65, 64, 0, 'note_off'),
#  (65, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (72, 64, 192, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (65, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 192, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 192, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 192, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (74, 64, 192, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 192, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (74, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (79, 64, 0, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (76, 64, 192, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 192, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (74, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (67, 92, 96, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (69, 64, 192, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 192, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 192, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 192, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 192, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (66, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 384, 'note_off'),
#  (66, 64, 0, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 192, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 192, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (59, 92, 0, 'note_on'),
#  (59, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (59, 92, 0, 'note_on'),
#  (59, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (57, 92, 0, 'note_on'),
#  (57, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (59, 92, 0, 'note_on'),
#  (59, 64, 96, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (69, 92, 768, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (67, 92, 768, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 192, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (64, 64, 192, 'note_off'),
#  (60, 64, 0, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 192, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (60, 64, 0, 'note_off'),
#  (59, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (59, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (66, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 192, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 192, 'note_off'),
#  (66, 64, 0, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 192, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 192, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 192, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 192, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (66, 92, 0, 'note_on'),
#  (62, 92, 192, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (66, 64, 0, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (68, 92, 0, 'note_on'),
#  (68, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (69, 64, 192, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 192, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 192, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 192, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 192, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 192, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (72, 64, 192, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 192, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (68, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 384, 'note_off'),
#  (68, 64, 0, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 192, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 192, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (74, 92, 96, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (77, 64, 0, 'note_off'),
#  (76, 92, 672, 'note_on'),
#  (72, 92, 96, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (74, 92, 672, 'note_on'),
#  (71, 92, 96, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (68, 92, 0, 'note_on'),
#  (68, 64, 96, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (72, 92, 672, 'note_on'),
#  (69, 92, 96, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (64, 92, 768, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (60, 64, 0, 'note_off'),
#  (59, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (59, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (78, 92, 0, 'note_on'),
#  (78, 64, 96, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (75, 92, 0, 'note_on'),
#  (75, 64, 96, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (66, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (60, 92, 0, 'note_on'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (60, 64, 0, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (75, 92, 0, 'note_on'),
#  (75, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 192, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (78, 92, 0, 'note_on'),
#  (78, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 192, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 192, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (78, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (78, 64, 192, 'note_off'),
#  (83, 92, 0, 'note_on'),
#  (83, 64, 192, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (83, 92, 0, 'note_on'),
#  (78, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (78, 64, 0, 'note_off'),
#  (83, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 192, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (81, 92, 0, 'note_on'),
#  (81, 64, 96, 'note_off'),
#  (83, 92, 0, 'note_on'),
#  (83, 64, 192, 'note_off'),
#  (81, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (81, 64, 96, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (75, 92, 0, 'note_on'),
#  (78, 92, 0, 'note_on'),
#  (78, 64, 384, 'note_off'),
#  (75, 64, 0, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (83, 92, 0, 'note_on'),
#  (78, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 192, 'note_off'),
#  (78, 64, 0, 'note_off'),
#  (83, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (76, 92, 0, 'note_on'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (67, 92, 0, 'note_on'),
#  (67, 64, 96, 'note_off'),
#  (76, 64, 0, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (81, 92, 0, 'note_on'),
#  (81, 64, 96, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (81, 92, 0, 'note_on'),
#  (81, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (81, 92, 0, 'note_on'),
#  (81, 64, 96, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (81, 92, 0, 'note_on'),
#  (81, 64, 96, 'note_off'),
#  (78, 92, 0, 'note_on'),
#  (78, 64, 96, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (66, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (66, 64, 0, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (66, 92, 0, 'note_on'),
#  (66, 64, 96, 'note_off'),
#  (74, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (74, 92, 0, 'note_on'),
#  (74, 64, 96, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (77, 92, 0, 'note_on'),
#  (77, 64, 96, 'note_off'),
#  (79, 92, 0, 'note_on'),
#  (79, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (62, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (62, 64, 0, 'note_off'),
#  (64, 92, 0, 'note_on'),
#  (72, 92, 0, 'note_on'),
#  (72, 64, 96, 'note_off'),
#  (64, 64, 0, 'note_off'),
#  (67, 92, 0, 'note_on'),
#  (60, 92, 0, 'note_on'),
#  (60, 64, 96, 'note_off'),
#  (67, 64, 0, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (62, 92, 0, 'note_on'),
#  (62, 64, 96, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (72, 92, 0, 'note_on'),
#  (64, 92, 0, 'note_on'),
#  (64, 64, 96, 'note_off'),
#  (72, 64, 0, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (66, 64, 0, 'note_off'),
#  (78, 92, 0, 'note_on'),
#  (78, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (78, 92, 0, 'note_on'),
#  (78, 64, 96, 'note_off'),
#  (73, 92, 0, 'note_on'),
#  (73, 64, 96, 'note_off'),
#  (78, 92, 0, 'note_on'),
#  (78, 64, 96, 'note_off'),
#  (76, 92, 0, 'note_on'),
#  (76, 64, 96, 'note_off'),
#  (78, 92, 0, 'note_on'),
#  (78, 64, 96, 'note_off'),
#  (75, 92, 0, 'note_on'),
#  (75, 64, 96, 'note_off'),
#  (63, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (63, 64, 0, 'note_off'),
#  (61, 92, 0, 'note_on'),
#  (69, 92, 0, 'note_on'),
#  (69, 64, 96, 'note_off'),
#  (61, 64, 0, 'note_off'),
#  (63, 92, 0, 'note_on'),
#  (71, 92, 0, 'note_on'),
#  (71, 64, 96, 'note_off'),
#  (63, 64, 0, 'note_off'),
#  (66, 92, 0, 'note_on'),
#  (59, 92, 0, 'note_on'),
#  (59, 64, 96, 'note_off'),
#  (66, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (63, 92, 0, 'note_on'),
#  (63, 64, 96, 'note_off'),
#  (71, 64, 0, 'note_off'),
#  (69, 92, 0, 'note_on'),
#  (61, 92, 0, 'note_on'),
#  (61, 64, 96, 'note_off'),
#  (69, 64, 0, 'note_off'),
#  (71, 92, 0, 'note_on'),
#  (63, 92, 0, 'note_on'),
#  ...]

# %%
from mido import Message, MidiFile, MidiTrack

mid = MidiFile()
track = MidiTrack()
mid.tracks.append(track)




for note, velocity, time, type in song:
    track.append(mido.Message(type, note=note, velocity=velocity, time=time))
    #track.append(message)
    
mid.save('new_song.mid')

# %%
training_set = pd.DataFrame(song)
print(training_set.head())
print()
print(training_set.shape)
del training_set[1]
del training_set[2]
del training_set[3]
training_set = training_set.to_numpy()
print(training_set.shape)
# Out:
#     0   1    2         3
# 0  67  92    0   note_on
# 1  72  92    0   note_on
# 2  72  64  192  note_off
# 3  76  92    0   note_on
# 4  76  64   96  note_off
#
# (2974, 4)
# (2974, 1)

# %%
training_set[:10]
# Out:
# array([[67],
#        [72],
#        [72],
#        [76],
#        [76],
#        [74],
#        [74],
#        [67],
#        [72],
#        [72]], dtype=int64)

# %%
"""
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
"""
training_set_scaled = training_set
training_set_scaled
# Out:
# array([[67],
#        [72],
#        [72],
#        ...,
#        [72],
#        [67],
#        [64]], dtype=int64)

# %%
X_train = []
y_train = []
for i in range(60, 2700):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i:i+60, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))

# %%
y_train
# Out:
# array([[[76],
#         [74],
#         [74],
#         ...,
#         [76],
#         [77],
#         [77]],
#
#        [[74],
#         [74],
#         [76],
#         ...,
#         [77],
#         [77],
#         [72]],
#
#        [[74],
#         [76],
#         [76],
#         ...,
#         [77],
#         [72],
#         [72]],
#
#        ...,
#
#        [[64],
#         [67],
#         [67],
#         ...,
#         [64],
#         [64],
#         [62]],
#
#        [[67],
#         [67],
#         [65],
#         ...,
#         [64],
#         [62],
#         [62]],
#
#        [[67],
#         [65],
#         [65],
#         ...,
#         [62],
#         [62],
#         [64]]], dtype=int64)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# -----------------------------------------------------------------------
# ModuleNotFoundError                   Traceback (most recent call last)
# <ipython-input-19-0bdefdd9183a> in <module>
# ----> 1 from tesnsorflow.keras.models import Sequential
#       2 from keras.layers import Dense
#       3 from keras.layers import LSTM
#       4 from keras.layers import Dropout
#
# ModuleNotFoundError: No module named 'tesnsorflow'

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM, Dropout, Flatten
from tensorflow.keras import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(LSTM(units = 50, return_sequences = True))
model.add(LSTM(units = 50, return_sequences = True))
model.add(LSTM(units = 50, return_sequences = True))
model.add(LSTM(units = 1, return_sequences = True))


model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Train on 2640 samples
# Epoch 1/100
#   32/2640 [..............................] - ETA: 6:01
# -----------------------------------------------------------------------
# KeyboardInterrupt                     Traceback (most recent call last)
# <ipython-input-31-be37e0e0981d> in <module>
# ----> 1 model.fit(X_train, y_train, epochs = 100, batch_size = 32)
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     613       # This is the first call of __call__, so we have to initialize.
#     614       initializers = []
# --> 615       self._initialize(args, kwds, add_initializers_to=initializers)
#     616     finally:
#     617       # At this point we know that the initialization is complete (or less
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     495     self._concrete_stateful_fn = (
#     496         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 497             *args, **kwds))
#     498
#     499     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2387       args, kwargs = None, None
#    2388     with self._lock:
# -> 2389       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2390     return graph_function
#    2391
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    2701
#    2702       self._function_cache.missed.add(call_context_key)
# -> 2703       graph_function = self._create_graph_function(args, kwargs)
#    2704       self._function_cache.primary[cache_key] = graph_function
#    2705       return graph_function, args, kwargs
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2591             arg_names=arg_names,
#    2592             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2593             capture_by_value=self._capture_by_value),
#    2594         self._function_attributes,
#    2595         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     976                                           converted_func)
#     977
# --> 978       func_outputs = python_func(*func_args, **func_kwargs)
#     979
#     980       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     437         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     438         # the function a weak reference to itself to avoid a reference cycle.
# --> 439         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     440     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     441
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in distributed_function(input_iterator)
#      83     args = _prepare_feed_values(model, input_iterator, mode, strategy)
#      84     outputs = strategy.experimental_run_v2(
# ---> 85         per_replica_function, args=args)
#      86     # Out of PerReplica outputs reduce or pick values to return.
#      87     all_outputs = dist_utils.unwrap_output_dict(
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py in experimental_run_v2(self, fn, args, kwargs)
#     761       fn = autograph.tf_convert(fn, ag_ctx.control_status_ctx(),
#     762                                 convert_by_default=False)
# --> 763       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     764
#     765   def reduce(self, reduce_op, value, axis):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    1817       kwargs = {}
#    1818     with self._container_strategy().scope():
# -> 1819       return self._call_for_each_replica(fn, args, kwargs)
#    1820
#    1821   def _call_for_each_replica(self, fn, args, kwargs):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    2162         self._container_strategy(),
#    2163         replica_id_in_sync_group=constant_op.constant(0, dtypes.int32)):
# -> 2164       return fn(*args, **kwargs)
#    2165
#    2166   def _reduce_to(self, reduce_op, value, destinations):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     290   def wrapper(*args, **kwargs):
#     291     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 292       return func(*args, **kwargs)
#     293
#     294   if inspect.isfunction(func) or inspect.ismethod(func):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics, standalone)
#     431       y,
#     432       sample_weights=sample_weights,
# --> 433       output_loss_metrics=model._output_loss_metrics)
#     434
#     435   if reset_metrics:
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     310           sample_weights=sample_weights,
#     311           training=True,
# --> 312           output_loss_metrics=output_loss_metrics))
#     313   if not isinstance(outs, list):
#     314     outs = [outs]
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     267           model._backwards(tape, scaled_total_loss)
#     268         else:
# --> 269           grads = tape.gradient(scaled_total_loss, trainable_weights)
#     270           if isinstance(model.optimizer,
#     271                         loss_scale_optimizer.LossScaleOptimizer):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1027         output_gradients=output_gradients,
#    1028         sources_raw=flat_sources_raw,
# -> 1029         unconnected_gradients=unconnected_gradients)
#    1030
#    1031     if not self._persistent:
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\function.py in _backward_function(*args)
#     786     def _backward_function(*args):
#     787       call_op = outputs[0].op
# --> 788       return self._rewrite_forward_and_call_backward(call_op, *args)
#     789     return _backward_function, outputs
#     790
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\eager\function.py in _rewrite_forward_and_call_backward(self, op, *doutputs)
#     716     op._add_outputs(
#     717         forward_function._output_types[len(op.outputs):],
# --> 718         forward_function._output_shapes[len(op.outputs):])
#     719     for i in range(len(op.outputs)):
#     720       func_graph_output = forward_function._func_graph_outputs[i]
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\framework\ops.py in _add_outputs(self, types, shapes)
#    2142       t = Tensor(self, orig_num_outputs + i, types[i])
#    2143       self._outputs.append(t)
# -> 2144       t.set_shape(shapes[i])
#    2145
#    2146   def __str__(self):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow_core\python\framework\ops.py in set_shape(self, shape)
#     632           self._as_tf_output(),
#     633           dim_list,
# --> 634           unknown_shape)
#     635     except errors.InvalidArgumentError as e:
#     636       # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:

# %%
y_predict = model.predict(X_train)

# %%
y_predict

# %%
created_song = pd.DataFrame(song)

# %%
created_song
