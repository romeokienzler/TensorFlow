# %% [markdown]
# Credits / Inspired by => https://github.com/mwitiderrick/stockprice

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_input = np.arange(10000)
training_set = pd.DataFrame(data_input)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))

"""
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
"""
regressor.add(LSTM(units = 50))

#regressor.add(Dropout(0.2))


regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 7.8615e-04
# Epoch 2/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 1.2981e-06
# Epoch 3/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 5.4842e-08
# Epoch 4/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 4.6624e-08
# Epoch 5/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 2.8908e-08
# Epoch 6/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 1.9507e-08
# Epoch 7/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 1.3433e-08
# Epoch 8/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 8.3874e-09
# Epoch 9/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 5.3801e-09
# Epoch 10/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 3.2548e-09
# Epoch 11/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 2.3682e-09
# Epoch 12/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.5005e-09
# Epoch 13/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 1.1250e-09
# Epoch 14/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 9.5010e-10
# Epoch 15/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 8.7661e-10
# Epoch 16/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 8.1795e-10
# Epoch 17/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 9.3703e-10
# Epoch 18/100
# 1975/1975 [==============================] - 7s 3ms/step - loss: 9.8402e-10
# Epoch 19/100
# 1975/1975 [==============================] - 8s 4ms/step - loss: 8.6220e-10
# Epoch 20/100
# 1975/1975 [==============================] - 8s 4ms/step - loss: 9.6273e-10
# Epoch 21/100
# 1975/1975 [==============================] - 8s 4ms/step - loss: 1.1843e-09
# Epoch 22/100
# 1975/1975 [==============================] - 7s 4ms/step - loss: 1.0495e-09
# Epoch 23/100
# 1975/1975 [==============================] - 7s 4ms/step - loss: 9.4719e-10
# Epoch 24/100
# 1975/1975 [==============================] - 7s 4ms/step - loss: 1.0600e-09
# Epoch 25/100
# 1975/1975 [==============================] - 8s 4ms/step - loss: 1.0496e-09
# Epoch 26/100
# 1975/1975 [==============================] - 8s 4ms/step - loss: 1.1284e-09
# Epoch 27/100
# 1975/1975 [==============================] - 7s 4ms/step - loss: 1.1328e-09
# Epoch 28/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 9.5764e-10
# Epoch 29/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 9.4913e-10
# Epoch 30/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 1.4103e-09
# Epoch 31/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 1.3674e-09
# Epoch 32/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 1.3731e-09
# Epoch 33/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 1.1746e-09
# Epoch 34/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 1.0267e-09
# Epoch 35/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.1964e-09
# Epoch 36/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.5260e-09
# Epoch 37/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.1921e-09
# Epoch 38/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 2.1355e-09
# Epoch 39/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 2.2009e-09
# Epoch 40/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.7806e-09
# Epoch 41/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.5124e-09
# Epoch 42/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.6925e-09
# Epoch 43/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 1.2405e-09
# Epoch 44/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.3749e-09
# Epoch 45/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 2.4831e-09
# Epoch 46/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 2.2558e-09
# Epoch 47/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 2.0209e-09
# Epoch 48/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 4.8733e-09
# Epoch 49/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 4.8982e-09
# Epoch 50/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.2407e-08
# Epoch 51/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 2.2193e-08
# Epoch 52/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 4.5981e-08
# Epoch 53/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 1.5274e-07
# Epoch 54/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 1.0357e-07
# Epoch 55/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 2.3438e-08
# Epoch 56/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 4.7327e-06
# Epoch 57/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 5.2455e-07
# Epoch 58/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 3.4820e-08
# Epoch 59/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 4.9389e-09
# Epoch 60/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 4.3100e-08
# Epoch 61/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 3.0585e-08
# Epoch 62/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 2.5283e-08
# Epoch 63/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 5.1404e-09
# Epoch 64/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.5501e-08
# Epoch 65/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 3.1020e-07
# Epoch 66/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 4.0420e-06
# Epoch 67/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.2974e-07
# Epoch 68/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 3.7049e-09
# Epoch 69/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 3.0653e-09
# Epoch 70/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 5.7104e-09
# Epoch 71/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.2106e-08
# Epoch 72/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.6311e-08
# Epoch 73/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 5.4999e-08
# Epoch 74/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 8.9237e-07
# Epoch 75/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.2844e-07
# Epoch 76/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 1.7468e-08
# Epoch 77/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 2.0122e-06
# Epoch 78/100
#  832/1975 [===========>..................] - ETA: 2s - loss: 1.1080e-06

# %%
y_predict = regressor.predict(X_train)

# %%
pd.DataFrame(sc.inverse_transform(y_predict))
# Out:
#                 0
# 0       25.611044
# 1       26.629213
# 2       27.647755
# 3       28.666445
# 4       29.684988
# ...           ...
# 1970  2054.816406
# 1971  2055.812744
# 1972  2056.809570
# 1973  2057.806152
# 1974  2058.802490
#
# [1975 rows x 1 columns]
