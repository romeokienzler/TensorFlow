# %% [markdown]
# <a href="https://colab.research.google.com/github/devprve/TensorFlow/blob/master/DeviPriya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Python sum of two numbers

# %%
a = 10
b = 20
c = a+b
print("sum is ",c)
# Out:
# sum is  30

# %%
import pandas as pd
mylist = [100,200,323]
result = pd.Series(mylist)
print(result)
# Out:
# 0    100
# 1    200
# 2    323
# dtype: int64

# %%
import numpy as np
arr = np.array((23,45,12))
print(arr)
print(type(arr))
# Out:
# [23 45 12]
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpt = np.array([0,4])
ypt = np.array([0,100])
plt.plot(xpt,ypt)
plt.show()
