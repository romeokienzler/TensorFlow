# %% [markdown]
# <a href="https://colab.research.google.com/github/naldo14/TensorFlow/blob/master/dwt_y.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pywt
import sys
import h5py #librerua para crear archivos , h5py
import pandas as pd
import math
from scipy.fft import fft, fftfreq

# %%
#hacer el mounted de mi cuenta drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sys.path.insert(0,"/content/drive/My Drive/Colab Notebooks")
import unzipmodule
import graficador

# %%
def z_score_normalization_from_coeffs(coeffs):
    energies = []
    for sub_array in coeffs:
        energy = np.sum(np.abs(sub_array) ** 2)
        energies.append(energy)

    mean_energy = np.mean(energies)
    std_energy = np.std(energies)

    # Calculate Z-scores
    z_scores = [(energy - mean_energy) / std_energy for energy in energies]

    return z_scores

# %%
def get_selected_key_and_data(h5py_file_path, index=0):
    with h5py.File(h5py_file_path, 'r') as h5_file:
        keys_1 = list(h5_file.keys())
        selected_key = keys_1[index]
        selected_data = h5_file[selected_key][:]
        print("Selected Key:", selected_key)
    return selected_key, selected_data

# %%
def get_lengths_array(coeffs, upper_level):
    sample_counts = [len(arr) for arr in coeffs]
    time_arrays = [np.linspace(0, upper_level, num=samples, endpoint=False) for samples in sample_counts]
    return time_arrays

# %%
def plot_graphs(time_arrays_1, coeffs_1, time_arrays_2, coeffs_2):
    num_graphs = len(time_arrays_1)  # Assuming both sets have the same length

    title = [None] * num_graphs
    title[0] = "A" + str(num_graphs - 1)
    title[1] = "D" + str(num_graphs - 1)

    for i in range(2, num_graphs):
        title[i] = "D" + str(num_graphs - i)

    for i in range(num_graphs):
        plt.figure(figsize=(12, 5))  # Adjust the figure size as needed
        # Create titles based on coefficient array lengths
        title_set_1 = title[i]
        title_set_2 = title[i]

        # Check if index is within the range of arrays
        if i < len(time_arrays_1) and i < len(coeffs_1):
            # Plot the first set (time_arrays_1 vs coeffs_1)
            plt.subplot(1, 2, 1)
            plt.plot(time_arrays_1[i], coeffs_1[i], label=title_set_1, color='red')
            plt.xlabel('Time')
            plt.ylabel('Coefficient Value')
            plt.legend()
            plt.title(f'Graph {i} - Set 1: {title_set_1}')

            # Plot the second set (time_arrays_2 vs coeffs_2)
            plt.subplot(1, 2, 2)
            plt.plot(time_arrays_2[i], coeffs_2[i], label=title_set_2, color='blue')
            plt.xlabel('Time')
            plt.ylabel('Coefficient Value')
            plt.legend()
            plt.title(f'Graph {i} - Set 2: {title_set_2}')

            plt.tight_layout()  # Adjust the layout for better visualization
            plt.show()  # Display the current plot window

    return title

# %%
def band_maker(coeffs, fs, title):
    p = len(coeffs)- 1
    low_frequencies = [None] * len(coeffs)
    high_frequencies = [None] * len(coeffs)

    # low_frequencies[0] = 0
    # high_frequencies[0] = fs / (2 ** (p) * 2)
    for i in range(0, len(coeffs)):
         high_frequencies[i] = fs / (2 ** (p+-i + 1))
    low_frequencies[0]=0
    low_frequencies[1:len(low_frequencies)]= high_frequencies[:len(low_frequencies) - 1]



    return  high_frequencies,low_frequencies

# %%
def frequencies_maker(N,fs,d,D,theta):
  theta=(theta/180)*np.pi
  FTF=(fs/2)*(1-d/D*np.cos(theta))
  BPFI=(N*fs/2)*(1+d/D*np.cos(theta))
  BPFO=(N*fs/2)*(1-d/D*np.cos(theta))
  BSF=(D*fs/d)*(1-(d/D)**2*np.cos(theta))
  return(FTF,BPFI,BPFO,BSF)

# %%
#celda para crear la lista con los paths de mi data
paths=[] #creo la lista de pahts
names=[] #creo la lista de nombres
output_file=[]
paths.append('/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/vibration_1')
paths.append('/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/part1')
paths.append('/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/part2')
paths.append('/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/part3')
names.append('vibration')
names.append('part1')
names.append('part2')
names.append('part3')
output_file.append('/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/vibration_1/vibration')
output_file.append('/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/part1/part1')
output_file.append('/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/part2/part2')
output_file.append('/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/part3/part3')

# %%
 print(pywt.families())
# Out:
# ['haar', 'db', 'sym', 'coif', 'bior', 'rbio', 'dmey', 'gaus', 'mexh', 'morl', 'cgau', 'shan', 'fbsp', 'cmor']

# %%
print(pywt.wavelist('db'))
# Out:
# ['db1', 'db2', 'db3', 'db4', 'db5', 'db6', 'db7', 'db8', 'db9', 'db10', 'db11', 'db12', 'db13', 'db14', 'db15', 'db16', 'db17', 'db18', 'db19', 'db20', 'db21', 'db22', 'db23', 'db24', 'db25', 'db26', 'db27', 'db28', 'db29', 'db30', 'db31', 'db32', 'db33', 'db34', 'db35', 'db36', 'db37', 'db38']

# %%
FTF,BPFI,BPFO,BSF=frequencies_maker(9,50.17,7.90,38.5,0)
data = {
    'Name': ['Fundamental train frequency (FTF)', 'Ball pass frequency inner (BPFI)', 'Ball pass frequency outer (BPFO)','Ball spin frequency (BSF)'],
    'Values (HZ)': [FTF, BPFI, BPFO,BSF]
}

# Create a dataframe from the dictionary
df = pd.DataFrame(data)

# Print the dataframe
print(df)
# Out:
#                                 Name  Values (HZ)
# 0  Fundamental train frequency (FTF)    19.937688
# 1   Ball pass frequency inner (BPFI)   272.090805
# 2   Ball pass frequency outer (BPFO)   179.439195
# 3          Ball spin frequency (BSF)   234.204744

# %%
## calculo el nivel del banco de filtro:
fs=math.ceil(FTF) #frecuencia natural , se usa la del train frequencie
fe=25.6e3 # frecuencia de sampleo
n = math.ceil(math.log(fe / fs) / math.log(2)) +2
level = n

# %%
time_array=graficador.plot_data_from_h5py(output_file[3])
# Out:
# Available files:
# 1. vibration_ball_5
# 2. vibration_ball_6
# 3. vibration_inner_5
# 4. vibration_inner_6
# 5. vibration_normal_5
# 6. vibration_normal_6
# 7. vibration_outer_5
# 8. vibration_outer_6
# Enter the index of the file you want to plot: 4

# %%
h5py_file_path=output_file[3]
selected_key_fault,selected_data_fault=get_selected_key_and_data(h5py_file_path, index=6)
# Out:
# Selected Key: vibration_outer_5

# %%
w = pywt.Wavelet('db38')
signal_faulty= selected_data_fault[:,3] ##rodamiento B bajo falla (eje y)
# # Perform DWT
coeffs_2 = pywt.wavedec(signal_faulty, w, level=level)
time_arrays_2=get_lengths_array(coeffs_2,300)

# %%
time_array=graficador.plot_data_from_h5py(output_file[1])
# Out:
# Available files:
# 1. vibration_ball_0
# 2. vibration_ball_1
# 3. vibration_ball_2
# 4. vibration_ball_constant
# 5. vibration_inner_0
# 6. vibration_inner_1
# 7. vibration_inner_2
# 8. vibration_inner_constant
# 9. vibration_normal_0
# 10. vibration_normal_1
# 11. vibration_normal_2
# 12. vibration_normal_constant
# 13. vibration_outer_0
# 14. vibration_outer_1
# 15. vibration_outer_2
# 16. vibration_outer_constant
# Enter the index of the file you want to plot: 10

# %%
h5py_file_path=output_file[1]
selected_key_healty,selected_data_healty=get_selected_key_and_data(h5py_file_path, index=9)
# Out:
# Selected Key: vibration_normal_1

# %%
##3calculo  B en el eje y sano
w = pywt.Wavelet('db38')
signal_healty= selected_data_healty [:,3]
# # Perform DWT
coeffs_1 = pywt.wavedec(signal_healty, w, level=level)
time_arrays_1=get_lengths_array(coeffs_1,300)

# %%
title=plot_graphs(time_arrays_1, coeffs_1, time_arrays_2, coeffs_2)

# %%
fs = 25.6e3
high_frequencies,  low_frequencies = band_maker(coeffs_2, fs, title)
df = pd.DataFrame({'Coefficient': title, 'Low Frequency': low_frequencies, 'High Frequency': high_frequencies})
df
# Out:
#    Coefficient  Low Frequency  High Frequency
# 0          A13         0.0000          1.5625
# 1          D13         1.5625          3.1250
# 2          D12         3.1250          6.2500
# 3          D11         6.2500         12.5000
# 4          D10        12.5000         25.0000
# 5           D9        25.0000         50.0000
# 6           D8        50.0000        100.0000
# 7           D7       100.0000        200.0000
# 8           D6       200.0000        400.0000
# 9           D5       400.0000        800.0000
# 10          D4       800.0000       1600.0000
# 11          D3      1600.0000       3200.0000
# 12          D2      3200.0000       6400.0000
# 13          D1      6400.0000      12800.0000

# %%
normalized_energies_faulty=z_score_normalization_from_coeffs(coeffs_2)

# %%
normalized_energies_healty=z_score_normalization_from_coeffs(coeffs_1)

# %%
# Normalize the energies_healty array
df1 = pd.DataFrame({ 'Nivel de energia rodamiento sano normalizado':  normalized_energies_healty, 'Nivel de energia rodamiento bajo falla normalizado ': normalized_energies_faulty})
df1
# Out:
#     Nivel de energia rodamiento sano normalizado  \
# 0                                      -0.545065
# 1                                      -0.548299
# 2                                      -0.548306
# 3                                      -0.548327
# 4                                      -0.548263
# 5                                      -0.547896
# 6                                      -0.546767
# 7                                      -0.547193
# 8                                      -0.541271
# 9                                      -0.352899
# 10                                     -0.297799
# 11                                      1.406379
# 12                                      2.552514
# 13                                      1.613191
#
#     Nivel de energia rodamiento bajo falla normalizado
# 0                                           -0.511245
# 1                                           -0.532083
# 2                                           -0.532115
# 3                                           -0.532153
# 4                                           -0.531474
# 5                                           -0.530686
# 6                                           -0.531671
# 7                                           -0.531778
# 8                                           -0.526892
# 9                                           -0.399114
# 10                                          -0.361774
# 11                                           1.011299
# 12                                           2.270413
# 13                                           2.239273

# %%
def find_indices_with_name(h5py_file_path, target_name): # #esta funcion me permite buscar los indices asociados a a mi palabra target
    indices = []

    with h5py.File(h5py_file_path, 'r') as h5_file:
        keys = list(h5_file.keys())
        for index, key in enumerate(keys):
            if target_name in key:
                indices.append(index)

    return indices

# %%
def get_selected_keys_and_data(h5py_file_path, target_name, index): #funcion que en base a los indices me devuelve las keys
    selected_keys = []

    with h5py.File(h5py_file_path, 'r') as h5_file:
        keys = list(h5_file.keys())
        for key in keys:
            if target_name in key:
                selected_keys.append(key)


    return selected_keys

# %%
def return_data(output_file, target_name):
  all_selected_keys_1 = []

  for file_path in output_file:
      indices = find_indices_with_name(file_path, target_name)
      selected_keys = get_selected_keys_and_data(file_path,target_name, indices)

      for key in (selected_keys):
          all_selected_keys_1.append([key])
  all_keys= [None] * len(all_selected_keys_1)
  ##########################################
  for i in range(0,len(all_selected_keys_1)): # aqui creo la lista para guardar los string de las key
      all_keys[i]=all_selected_keys_1[i][0]
      #######################################
  selected_data = []
  #########################################
  for selected_key in all_keys: # algoritmo para obtener la data en el orden de las keys
    for file_path in output_file:
      with h5py.File(file_path, 'r') as h5_file:
        keys = list(h5_file.keys())
        if selected_key in keys:
          #print("esta en el archivo")
          selected_data.append( h5_file[selected_key][:])

        else:
          #print('no esta ')
          continue

  return (all_keys,selected_data)

# %%
def calculate_energy_levels(selected_data, wavelet='db38', level=5): #funcion para calcular los niveles energeticos de los data set
    w = pywt.Wavelet(wavelet)
    array_dwt = np.empty((len(selected_data), selected_data[0].shape[1]), dtype=list)

    for j in range(len(selected_data)):
        for i in range(selected_data[j].shape[1]):
            coeffs = pywt.wavedec(selected_data[j][:, i], w, level=level)
            energies_levels = [np.sum(np.abs(coeffs)**2) for coeffs in coeffs]
            array_dwt[j, i] = energies_levels

    return array_dwt

# %%
def normalize_energies(energies_level):
    mean_energy = np.mean(energies_level)
    std_energy = np.std(energies_level)

    # Calculate Z-scores
    z_scores = [(energy - mean_energy) / std_energy for energy in energies_level]
    return z_scores

# %%
def data_set_two(coeff, all_keys_n_w_constant, all_keys_f_w_constant, energy_level_n_w_constant, energy_level_f_w_constant):  #funcion para determinar el nivel energetico para los rodamientos A y B bajo falla en el segundo data set
    energies_level_f_B = []
    energies_level_f_name_B = []
    energies_level_f_A = []
    energies_level_f_name_A = []

    for i, name_normal in enumerate(all_keys_n_w_constant):
        for j, name_faulty in enumerate(all_keys_f_w_constant):
            if name_normal[0:3] == name_faulty[0:3]:
                if 2>1:  # eje y de la casa de rodamientos A
                    energies_level_f_A.append(energy_level_f_w_constant[j][1]) #tenia trozo de error aqui , el 1 indica el eje y del rodamiento A
                    energies_level_f_name_A.append(name_faulty)
                if 2>1:  # eje y de la casa de rodamientos B
                    energies_level_f_B.append(energy_level_f_w_constant[j][3]) #el 3 indica el eje y del rodamiento B
                    energies_level_f_name_B.append(name_faulty)

    return energies_level_f_A, energies_level_f_B, energies_level_f_name_A, energies_level_f_name_B

# %%
def concatenation(energies):### funcion para convertir los void array in normal array to train the network
    converted_arrays = [np.array(element[0]) for element in energies]
    resulting_array = np.vstack(converted_arrays)

    return resulting_array

# %%
def create_mask_array(layers):
    # Initialize an empty mask array
    mask_array = np.zeros(len(layers), dtype=int)

    # Check each element of the 'layers' array
    for i, layer in enumerate(layers):
        # Check if the word "normal" or "Normal" is not in the layer name
        if "normal" not in layer.lower() and "Normal" not in layer:
            mask_array[i] = 1  # Set the corresponding element to 1

    return mask_array

# %% [markdown]
# ### Parte  1 segundo data set

# %% [markdown]
# Calculo de los coeficientes energeticos para el caso vibration_normal (velocidad variable)

# %%
all_keys_normal,selected_data_normal=return_data(output_file, "normal")

# %%
energies_level_normal=calculate_energy_levels(selected_data_normal, wavelet='db38', level=level)#aqui calculo los niveles energeticos para los 4 rodamientos

# %% [markdown]
# Calculo de los coeficientes energeticos para el caso vibration_ball (velocidad variable)

# %%
all_keys_ball,selected_data_ball=return_data(output_file, "ball")

# %%
energies_level_ball=calculate_energy_levels(selected_data_ball, wavelet='db38', level=level) #aqui calculo los niveles energeticos para los 4 rodamientos

# %% [markdown]
# Calculo de los coeficientes energeticos para el caso vibration_inner  (velocidad variable)

# %%
all_keys_inner,selected_data_inner=return_data(output_file, "inner")

# %%
energies_level_inner=calculate_energy_levels(selected_data_inner, wavelet='db38', level=level)#aqui calculo los niveles energeticos para los 4 rodamientos

# %% [markdown]
# Calculo de los coeficientes energeticos para el caso vibration_outer (velocidad variable)

# %%
all_keys_outer,selected_data_outer=return_data(output_file, "outer")

# %%
energies_level_outer=calculate_energy_levels(selected_data_outer, wavelet='db38', level=level)#aqui calculo los niveles energeticos para los 4 rodamientos

# %% [markdown]
# Seleciono todo la data

# %%
# trabajo solo con el eje y
# Create structured arrays with specific data types and length
energies_level_outer_B =[]
energies_level_outer_name =[]
energies_level_inner_B =[]
energies_level_inner_name =[]
energies_level_ball_B =[]
energies_level_ball_name =[]

for i in range(0, energies_level_normal.shape[0]):
    if 2>1:# coefficnete 7
        energies_level_outer_B.append(energies_level_outer[i][3]) # el tres indica que solo estoy trabajando con el eje y del rodamiento B
        energies_level_outer_name.append(all_keys_outer[i])
    if 2>1: # coeficiente 6
        energies_level_inner_B.append(energies_level_inner[i][3])
        energies_level_inner_name.append(all_keys_inner[i])
    if 2>1: # coeficiente 6
        energies_level_ball_B.append( energies_level_ball[i][3])
        energies_level_ball_name.append(all_keys_ball[i])

# %%
energies_level_ball_name
# Out:
# ['vibration_ball_0',
#  'vibration_ball_1',
#  'vibration_ball_2',
#  'vibration_ball_constant',
#  'vibration_ball_3',
#  'vibration_ball_4',
#  'vibration_ball_5',
#  'vibration_ball_6']

# %% [markdown]
# Calculo los niveles energeticos normalizados para el caso de rodamiento sano

# %%
dtype = np.dtype([
    ('field0', object),  # You can change 'field0' to a more meaningful name
    ('field1', object),  # You can change 'field1' to a more meaningful name
    ('field2', object),  # You can change 'field2' to a more meaningful name
    ('field3', object)   # You can change 'field3' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_normal_normalized = np.empty(len(energies_level_normal), dtype=dtype)
for i, x in enumerate(all_keys_normal):
  energies_level_normal_normalized['field0'][i] = normalize_energies(energies_level_normal[i][0])
  energies_level_normal_normalized['field1'][i] = normalize_energies(energies_level_normal[i][1])#eje y rodamiento A
  energies_level_normal_normalized['field2'][i] = normalize_energies(energies_level_normal[i][2])
  energies_level_normal_normalized['field3'][i] = normalize_energies(energies_level_normal[i][3])#eje y rodamiento B

#aqui trabajo con ambos ejes y ambos rodamientos la seleccion con el eje x la hago en la concatenacion

# %%
all_keys_normal
# Out:
# ['vibration_normal_0',
#  'vibration_normal_1',
#  'vibration_normal_2',
#  'vibration_normal_constant',
#  'vibration_normal_3',
#  'vibration_normal_4',
#  'vibration_normal_5',
#  'vibration_normal_6']

# %%
 energies_level_normal_normalized[0][3]==df1['Nivel de energia rodamiento sano normalizado']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento sano normalizado, dtype: bool

# %% [markdown]
# Calculo los niveles energeticos normalizados para el caso de falla en el elemento rodante

# %%
# Define your normalize_energies function (as shown previously)

# Create a structured array to store the normalized arrays
dtype = np.dtype([
    ('field0', object),  # You can change 'field0' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_ball_normalized = np.empty(len(energies_level_ball_B), dtype=dtype)

# Loop through each element in energies_level_normal and normalize the arrays
for i,x in enumerate(energies_level_ball_name):
    energies_level_ball_normalized['field0'][i] = normalize_energies(energies_level_ball_B[i]) ### pendiente, data donde esta almacenado los vectores a usar como entrenamiento en el orden dado por las listas de nombres

# %%
energies_level_ball_normalized[0][0]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %% [markdown]
# Calculo los niveles energeticos normalizados para el caso de falla en el anillo interno

# %%
# Define your normalize_energies function (as shown previously)

# Create a structured array to store the normalized arrays
dtype = np.dtype([
    ('field0', object),  # You can change 'field0' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_inner_normalized = np.empty(len(energies_level_inner_B), dtype=dtype)

# Loop through each element in energies_level_normal and normalize the arrays
for i,x in enumerate(energies_level_inner_name):
    energies_level_inner_normalized['field0'][i] = normalize_energies(energies_level_inner_B[i]) ### pendiente, data donde esta almacenado los vectores a usar como entrenamiento en el orden dado por las listas de nombres

# %%
energies_level_inner_normalized[0][0]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %% [markdown]
# Calculo los niveles energeticos normalizados para el caso de falla en el anillo externo

# %%
# Define your normalize_energies function (as shown previously)

# Create a structured array to store the normalized arrays
dtype = np.dtype([
    ('field0', object),  # You can change 'field0' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_outer_normalized = np.empty(len(energies_level_outer_B), dtype=dtype)

# Loop through each element in energies_level_normal and normalize the arrays
for i,x in enumerate(energies_level_outer_name):
    energies_level_outer_normalized['field0'][i] = normalize_energies(energies_level_outer_B[i])  ### pendiente, data donde esta almacenado los vectores a usar como entrenamiento en el orden dado por las listas de nombres

# %%
energies_level_outer_name
# Out:
# ['vibration_outer_0',
#  'vibration_outer_1',
#  'vibration_outer_2',
#  'vibration_outer_constant',
#  'vibration_outer_3',
#  'vibration_outer_4',
#  'vibration_outer_5',
#  'vibration_outer_6']

# %%
energies_level_outer_normalized[0][0]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %% [markdown]
# ## Parte 2 primer data set (velocidad constante , carga variable)

# %%
all_keys_normal_w_constant,selected_data_normal_w_constant=return_data(output_file, "Normal")
energies_level_normal_w_constant=calculate_energy_levels(selected_data_normal_w_constant, wavelet='db38', level=level)

# %%
all_keys_inner_w_constant,selected_data_inner_w_constant=return_data(output_file, "BPFI")
energies_level_inner_w_constant=calculate_energy_levels(selected_data_inner_w_constant, wavelet='db38', level=level)

# %%
### aqui esta bien el calculo de los niveles energeticos , la quinta columna de selcted_data es el tiempo
all_keys_outter_w_constant,selected_data_outter_w_constant=return_data(output_file, "BPFO")
energies_level_outter_w_constant=calculate_energy_levels(selected_data_outter_w_constant, wavelet='db38', level=level)

# %% [markdown]
# ### Calculo de los niveles energeticos por rodamiento (A y B)

# %%
energies_level_inner_A_constant, energies_level_inner_B_constant, energies_level_inner_name_A_constant, energies_level_inner_name_B_constant= data_set_two(8, all_keys_normal_w_constant, all_keys_inner_w_constant, energies_level_normal_w_constant, energies_level_inner_w_constant)

# %%
### aqu esta el error , ya lo resolvi ????
energies_level_outter_A_constant, energies_level_outter_B_constant, energies_level_outter_name_A_constant, energies_level_outter_name_B_constant= data_set_two(7, all_keys_normal_w_constant, all_keys_outter_w_constant, energies_level_normal_w_constant, energies_level_outter_w_constant)

# %% [markdown]
# ### calculo de los niveles normalizados para el caso de rodamiento sano

# %%
dtype = np.dtype([
    ('field0', object),  # You can change 'field0' to a more meaningful name
    ('field1', object),  # You can change 'field1' to a more meaningful name
    ('field2', object),  # You can change 'field2' to a more meaningful name
    ('field3', object)   # You can change 'field3' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_normal_w_constant_normalized = np.empty(len(energies_level_normal_w_constant), dtype=dtype)
for i, x in enumerate(all_keys_normal_w_constant):
  energies_level_normal_w_constant_normalized['field0'][i] = normalize_energies(energies_level_normal_w_constant[i][0]) #eje x rodamiento A
  energies_level_normal_w_constant_normalized['field1'][i] = normalize_energies(energies_level_normal_w_constant[i][1]) #eje y rodamiento A
  energies_level_normal_w_constant_normalized['field2'][i] = normalize_energies(energies_level_normal_w_constant[i][2]) #eje x rodamiento B
  energies_level_normal_w_constant_normalized['field3'][i] = normalize_energies(energies_level_normal_w_constant[i][3]) #eje y rodamiento B

# %%
all_keys_normal_w_constant
# Out:
# ['0Nm_Normal', '2Nm_Normal', '4Nm_Normal']

# %%
 energies_level_normal_w_constant_normalized[0][1]==df1['Nivel de energia rodamiento sano normalizado']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento sano normalizado, dtype: bool

# %% [markdown]
# ###Calculo de los niveles normalizados para el caso en el anillo interno y externo  por rodamiento (A y B)

# %% [markdown]
# Niveles normalizados anillo interno

# %%
# Create a structured array to store the normalized arrays
dtype = np.dtype([
    ('field0', object),  # You can change 'field0' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_inner_normalized_A_w_constant= np.empty(len(energies_level_inner_A_constant), dtype=dtype)

# Loop through each element in energies_level_normal and normalize the arrays
for i,x in enumerate(energies_level_inner_name_A_constant):
    energies_level_inner_normalized_A_w_constant['field0'][i] = normalize_energies(energies_level_inner_A_constant[i]) ### pendiente, data donde esta almacenado los vectores a usar como entrenamiento en el orden dado por las listas de nombres

# %%
# Define your normalize_energies function (as shown previously)

# Create a structured array to store the normalized arrays
dtype = np.dtype([
    ('field0', object),  # You can change 'field0' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_inner_normalized_B_w_constant= np.empty(len(energies_level_inner_B_constant), dtype=dtype)

# Loop through each element in energies_level_normal and normalize the arrays
for i,x in enumerate(energies_level_inner_name_B_constant):
    energies_level_inner_normalized_B_w_constant['field0'][i] = normalize_energies(energies_level_inner_B_constant[i]) ### pendiente, data donde esta almacenado los vectores a usar como entrenamiento en el orden dado por las listas de nombres

# %% [markdown]
# Niveles normalizados anillo externo

# %%
# Define your normalize_energies function (as shown previously)

# Create a structured array to store the normalized arrays
dtype = np.dtype([
    ('field0', object),  # You can change 'field0' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_outter_normalized_A_w_constant= np.empty(len(energies_level_outter_A_constant), dtype=dtype)

# Loop through each element in energies_level_normal and normalize the arrays
for i,x in enumerate(energies_level_outter_name_A_constant):
    energies_level_outter_normalized_A_w_constant['field0'][i] = normalize_energies(energies_level_outter_A_constant[i]) ##b# pendiente, data donde esta almacenado los vectores a usar como entrenamiento en el orden dado por las listas de nombres

# %%
# Define your normalize_energies function (as shown previously)

# Create a structured array to store the normalized arrays
dtype = np.dtype([
    ('numero', object),  # You can change 'field0' to a more meaningful name
])

# Create an empty structured array with the same length as energies_level_normal
energies_level_outter_normalized_B_w_constant= np.empty(len(energies_level_outter_B_constant), dtype=dtype)

# Loop through each element in energies_level_normal and normalize the arrays
for j,x in enumerate(energies_level_outter_name_B_constant):
    energies_level_outter_normalized_B_w_constant['numero'][j] = normalize_energies(energies_level_outter_B_constant[j]) ### pendiente, data donde esta almacenado los vectores a usar como entrenamiento en el orden dado por las listas de nombres

# %% [markdown]
# ### PARTE 3 CONCATENACION DE DATOS Y CREACION DE LAYERS

# %% [markdown]
# concatenacion de datos data set 2

# %%
energies_level_normal_normalized ## variable que contiene ambos rodamientos (sanos) segundo data set
print(all_keys_normal)
converted_arrays = [np.array(element[1]) for element in energies_level_normal_normalized] #eje Y del rodamiento A #segundo data set
converted_arrays_1 = [np.array(element[3]) for element in energies_level_normal_normalized] # eje Y del rodamiento B #srgundo data set
# Convert the list of arrays into a NumPy array
energies_level_normal_normalized_A = np.array(converted_arrays)
energies_level_normal_normalized_B= np.array(converted_arrays_1)
# Out:
# ['vibration_normal_0', 'vibration_normal_1', 'vibration_normal_2', 'vibration_normal_constant', 'vibration_normal_3', 'vibration_normal_4', 'vibration_normal_5', 'vibration_normal_6']

# %%
energies_level_normal_normalized_A[1]==df1['Nivel de energia rodamiento sano normalizado']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento sano normalizado, dtype: bool

# %%
energies_level_normal_normalized_B[1]==df1['Nivel de energia rodamiento sano normalizado']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento sano normalizado, dtype: bool

# %%
energies_level_ball_normalized ## variable que contiene solo rodamiento B  segundo data set
print(energies_level_ball_name)
energies_level_ball_normalized_array=concatenation(energies_level_ball_normalized) #solo tengo el eje y del rodamiento B
# Out:
# ['vibration_ball_0', 'vibration_ball_1', 'vibration_ball_2', 'vibration_ball_constant', 'vibration_ball_3', 'vibration_ball_4', 'vibration_ball_5', 'vibration_ball_6']

# %%
energies_level_ball_normalized_array[2]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %%
energies_level_inner_normalized ## variable que contiene solo rodamiento B  segundo data set
print(energies_level_inner_name)
energies_level_inner_normalized_array=concatenation(energies_level_inner_normalized)
# Out:
# ['vibration_inner_0', 'vibration_inner_1', 'vibration_inner_2', 'vibration_inner_constant', 'vibration_inner_3', 'vibration_inner_4', 'vibration_inner_5', 'vibration_inner_6']

# %%
energies_level_inner_normalized_array[7]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %%
energies_level_outer_normalized ## variable que contiene solo rodamiento B  segundo data set
print(energies_level_outer_name)
energies_level_outter_normalized_array=concatenation(energies_level_outer_normalized)
# Out:
# ['vibration_outer_0', 'vibration_outer_1', 'vibration_outer_2', 'vibration_outer_constant', 'vibration_outer_3', 'vibration_outer_4', 'vibration_outer_5', 'vibration_outer_6']

# %%
energies_level_outter_normalized_array[6]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %% [markdown]
# ### concatenacion de datos data set 1

# %% [markdown]
# rodamiento normal

# %%
# Check if the variables are defined
if 'converted_arrays' in locals() or 'converted_arrays' in globals():
    # Variables are defined, so delete them
    try:
        del converted_arrays, converted_arrays_1
    except NameError:
        pass

# Execute the code after deleting the variables
energies_level_normal_w_constant_normalized
print(all_keys_normal_w_constant)

converted_arrays = [np.array(element[1]) for element in energies_level_normal_w_constant_normalized] #eje Y del rodamiento A #P RIMER data se
converted_arrays_1 = [np.array(element[3]) for element in energies_level_normal_w_constant_normalized] #eje Y del rodamiento B  PRIMER data se

# Convert the list of arrays into a NumPy array
energies_level_normal_normalized_A_w_constant = np.array(converted_arrays)
energies_level_normal_normalized_B_w_constant = np.array(converted_arrays_1)
# Out:
# ['0Nm_Normal', '2Nm_Normal', '4Nm_Normal']

# %%
df1['Nivel de energia rodamiento sano normalizado']==energies_level_normal_normalized_A_w_constant[0]
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento sano normalizado, dtype: bool

# %%
energies_level_normal_normalized_B_w_constant[0]==df1['Nivel de energia rodamiento sano normalizado']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento sano normalizado, dtype: bool

# %% [markdown]
# rodamiento inner housing A

# %%
energies_level_inner_normalized_A_w_constant## variable que contiene solo rodamiento A primer data set
print(energies_level_inner_name_A_constant)
energies_level_inner_normalized_A_w_constant_array=concatenation(energies_level_inner_normalized_A_w_constant)
# Out:
# ['0Nm_BPFI_03', '0Nm_BPFI_10', '0Nm_BPFI_30', '2Nm_BPFI_03', '2Nm_BPFI_10', '2Nm_BPFI_30', '4Nm_BPFI_03', '4Nm_BPFI_10', '4Nm_BPFI_30']

# %%
energies_level_inner_normalized_A_w_constant_array[0]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %% [markdown]
# rodamiento inner housing B

# %%
energies_level_inner_normalized_B_w_constant## variable que contiene solo rodamiento B  primer data set
print(energies_level_inner_name_B_constant)
energies_level_inner_normalized_B_w_constant_array=concatenation(energies_level_inner_normalized_B_w_constant)
# Out:
# ['0Nm_BPFI_03', '0Nm_BPFI_10', '0Nm_BPFI_30', '2Nm_BPFI_03', '2Nm_BPFI_10', '2Nm_BPFI_30', '4Nm_BPFI_03', '4Nm_BPFI_10', '4Nm_BPFI_30']

# %%
energies_level_inner_normalized_B_w_constant_array[0]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %% [markdown]
# rodamiento outter housing A

# %%
energies_level_outter_normalized_A_w_constant## variable que contiene solo rodamiento A primer  data set
print(energies_level_outter_name_A_constant)
energies_level_outter_normalized_A_w_constant_array=concatenation(energies_level_outter_normalized_A_w_constant)
# Out:
# ['0Nm_BPFO_03', '0Nm_BPFO_10', '0Nm_BPFO_30', '2Nm_BPFO_03', '2Nm_BPFO_10', '2Nm_BPFO_30', '4Nm_BPFO_03', '4Nm_BPFO_10', '4Nm_BPFO_30']

# %%
energies_level_outter_normalized_A_w_constant_array[3]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %% [markdown]
# rodamiento outter housing B

# %%
energies_level_outter_normalized_B_w_constant## variable que contiene solo rodamiento B  primer  data set
print(energies_level_outter_name_B_constant)
energies_level_outter_normalized_B_w_constant_array=concatenation(energies_level_outter_normalized_B_w_constant)
# Out:
# ['0Nm_BPFO_03', '0Nm_BPFO_10', '0Nm_BPFO_30', '2Nm_BPFO_03', '2Nm_BPFO_10', '2Nm_BPFO_30', '4Nm_BPFO_03', '4Nm_BPFO_10', '4Nm_BPFO_30']

# %%
energies_level_outter_normalized_B_w_constant_array[3]==df1['Nivel de energia rodamiento bajo falla normalizado ']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# Name: Nivel de energia rodamiento bajo falla normalizado , dtype: bool

# %% [markdown]
# ### concatenacion final

# %%
layers=np.hstack((np.array(all_keys_normal),np.array(all_keys_normal),np.array(energies_level_inner_name),np.array(energies_level_outer_name),np.array(energies_level_ball_name),np.array(all_keys_normal_w_constant),np.array(all_keys_normal_w_constant,),np.array(energies_level_inner_name_A_constant),np.array(energies_level_inner_name_B_constant),np.array(energies_level_outter_name_A_constant),np.array(energies_level_outter_name_B_constant)))
#debo agregar la falla en el elemento rodante

# %%
y_hat=create_mask_array(layers)

# %%
y_hat.shape
# Out:
# (82,)

# %%
 x=np.vstack((energies_level_normal_normalized_A, energies_level_normal_normalized_B,energies_level_inner_normalized_array,energies_level_outter_normalized_array,energies_level_ball_normalized_array,energies_level_normal_normalized_A_w_constant ,energies_level_normal_normalized_B_w_constant,energies_level_inner_normalized_A_w_constant_array,energies_level_inner_normalized_B_w_constant_array,energies_level_outter_normalized_A_w_constant_array,energies_level_outter_normalized_B_w_constant_array ))

# %%
x.shape
# Out:
# (82, 14)

# %%
#creo el h5py de las features
data=x
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/features_y"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'w') as hf:
    hf.create_dataset('features_y', data=data)
with h5py.File(hdf5_file_path, 'r') as hf:
    x_features = hf['features_y'][:]

# %%
x_features.shape
# Out:
# (82, 14)

# %%
data=y_hat
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/y_targets"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'w') as hf:
    hf.create_dataset('y_targets', data=data)
with h5py.File(hdf5_file_path, 'r') as hf:
    y_targets = hf['y_targets'][:]

# %%
y_targets.shape
# Out:
# (82,)

# %% [markdown]
# ### Entrenar la red neuronal (al fin)

# %%
from sklearn.model_selection import train_test_split

# Assuming x is your dataset with shape (70, 14) and y is your labels
x_shape = x_features.shape[0]
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

# Split the dataset into a temporary training set and a test set
x_temp, x_test, y_temp, y_test = train_test_split(x_features, y_targets, test_size=test_ratio, random_state=42)

# Split the temporary dataset into a training set and a validation set
x_train, x_val, y_train, y_val = train_test_split(x_temp, y_temp, test_size=val_ratio / (1 - test_ratio), random_state=42)

# Now, x_train, y_train, x_val, y_val, x_test, and y_test contain the data and labels for each set

# Shuffle the rows
train_indices = np.random.permutation(len(x_train))
val_indices = np.random.permutation(len(x_val))
test_indices = np.random.permutation(len(x_test))

x_train, y_train = x_train[train_indices], y_train[train_indices]
x_val, y_val = x_val[val_indices], y_val[val_indices]
x_test, y_test = x_test[test_indices], y_test[test_indices]

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
### need to add some dropeout
# Define the model with kernel regularization
model = tf.keras.Sequential([
    tf.keras.layers.Dense(20, activation='relu', input_shape=(14,), kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(15, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(10, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(5, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])





# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.FalseNegatives(), tf.keras.metrics.FalsePositives()])

# def lr_schedule(epoch):
#     if epoch < 100:
#         return 0.001  # Initial learning rate for the first 100 epochs
#     elif epoch < 200:
#         return 0.0001  # Lower learning rate for the next 100 epochs
#     else:
#         return 0.00001  # Further lower learning rate for subsequent epochs

# # Create a learning rate scheduler callback
# lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lr_schedule)

# Include the callback in model training
# history = model.fit(x_train, y_train, epochs=600, validation_data=(x_val, y_val), callbacks=[lr_scheduler], verbose=2)
history = model.fit(x_train, y_train, epochs=1000, validation_data=(x_val, y_val), verbose=2)
# Plot the training loss and accuracy
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()


# Evaluate the model on the test data
test_loss, test_accuracy, false_negatives, false_positives = model.evaluate(x_test, y_test) #Returns the loss value & metrics values for the model in test mode (this is for testing time, with the testing dataset).

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
print(f"False Negatives: {false_negatives:.0f}")
print(f"False Positives: {false_positives:.0f}")

# Make predictions on test data
y_pred = model.predict(x_test)
y_pred_binary = (y_pred >= 0.5).astype(int)

# Calculate confusion matrix
confusion = confusion_matrix(y_test, y_pred_binary)
print("Confusion Matrix:")
print(confusion)
# Out:
# Epoch 1/1000
# 2/2 - 1s - loss: 1.1638 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1917 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 1s/epoch - 747ms/step
# Epoch 2/1000
# 2/2 - 0s - loss: 1.1520 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1807 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 3/1000
# 2/2 - 0s - loss: 1.1417 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1697 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 4/1000
# 2/2 - 0s - loss: 1.1322 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1590 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 5/1000
# 2/2 - 0s - loss: 1.1220 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1489 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 6/1000
# 2/2 - 0s - loss: 1.1129 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1381 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 7/1000
# 2/2 - 0s - loss: 1.1034 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1282 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 8/1000
# 2/2 - 0s - loss: 1.0944 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1197 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 9/1000
# 2/2 - 0s - loss: 1.0848 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1122 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 10/1000
# 2/2 - 0s - loss: 1.0782 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.1051 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 11/1000
# 2/2 - 0s - loss: 1.0711 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0980 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 12/1000
# 2/2 - 0s - loss: 1.0628 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0915 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 13/1000
# 2/2 - 0s - loss: 1.0563 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0855 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 40ms/epoch - 20ms/step
# Epoch 14/1000
# 2/2 - 0s - loss: 1.0490 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0797 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 15/1000
# 2/2 - 0s - loss: 1.0419 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0743 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 16/1000
# 2/2 - 0s - loss: 1.0352 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0679 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 17/1000
# 2/2 - 0s - loss: 1.0287 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0611 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 18/1000
# 2/2 - 0s - loss: 1.0227 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0554 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 19/1000
# 2/2 - 0s - loss: 1.0171 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0502 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 20/1000
# 2/2 - 0s - loss: 1.0109 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0454 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 53ms/epoch - 26ms/step
# Epoch 21/1000
# 2/2 - 0s - loss: 1.0048 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0394 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 22/1000
# 2/2 - 0s - loss: 0.9990 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0338 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 23/1000
# 2/2 - 0s - loss: 0.9935 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0285 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 24/1000
# 2/2 - 0s - loss: 0.9884 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0234 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 25/1000
# 2/2 - 0s - loss: 0.9827 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0184 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 26/1000
# 2/2 - 0s - loss: 0.9778 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0134 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 27/1000
# 2/2 - 0s - loss: 0.9725 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0081 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 28/1000
# 2/2 - 0s - loss: 0.9672 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 1.0027 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 29/1000
# 2/2 - 0s - loss: 0.9621 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9978 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 30/1000
# 2/2 - 0s - loss: 0.9570 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9931 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 40ms/epoch - 20ms/step
# Epoch 31/1000
# 2/2 - 0s - loss: 0.9525 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9881 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 32/1000
# 2/2 - 0s - loss: 0.9472 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9827 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 41ms/epoch - 20ms/step
# Epoch 33/1000
# 2/2 - 0s - loss: 0.9421 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9775 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 40ms/epoch - 20ms/step
# Epoch 34/1000
# 2/2 - 0s - loss: 0.9376 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9723 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 35/1000
# 2/2 - 0s - loss: 0.9331 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9674 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 36/1000
# 2/2 - 0s - loss: 0.9280 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9630 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 37/1000
# 2/2 - 0s - loss: 0.9236 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9583 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 42ms/epoch - 21ms/step
# Epoch 38/1000
# 2/2 - 0s - loss: 0.9189 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9534 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 40ms/epoch - 20ms/step
# Epoch 39/1000
# 2/2 - 0s - loss: 0.9146 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9488 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 42ms/epoch - 21ms/step
# Epoch 40/1000
# 2/2 - 0s - loss: 0.9104 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9441 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 42ms/epoch - 21ms/step
# Epoch 41/1000
# 2/2 - 0s - loss: 0.9057 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9391 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 42/1000
# 2/2 - 0s - loss: 0.9013 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9340 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 43/1000
# 2/2 - 0s - loss: 0.8976 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9289 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 44/1000
# 2/2 - 0s - loss: 0.8932 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9244 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 41ms/epoch - 20ms/step
# Epoch 45/1000
# 2/2 - 0s - loss: 0.8891 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9200 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 46/1000
# 2/2 - 0s - loss: 0.8849 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9157 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 53ms/epoch - 26ms/step
# Epoch 47/1000
# 2/2 - 0s - loss: 0.8808 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9108 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 48/1000
# 2/2 - 0s - loss: 0.8770 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9063 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 42ms/epoch - 21ms/step
# Epoch 49/1000
# 2/2 - 0s - loss: 0.8728 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.9019 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 50/1000
# 2/2 - 0s - loss: 0.8690 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8973 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 51/1000
# 2/2 - 0s - loss: 0.8651 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8930 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 52/1000
# 2/2 - 0s - loss: 0.8615 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8886 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 53/1000
# 2/2 - 0s - loss: 0.8576 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8844 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 54/1000
# 2/2 - 0s - loss: 0.8534 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8806 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 55/1000
# 2/2 - 0s - loss: 0.8496 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8765 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 56/1000
# 2/2 - 0s - loss: 0.8456 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8722 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 57/1000
# 2/2 - 0s - loss: 0.8421 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8681 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 58/1000
# 2/2 - 0s - loss: 0.8384 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8642 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 59/1000
# 2/2 - 0s - loss: 0.8345 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8607 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 60/1000
# 2/2 - 0s - loss: 0.8313 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8575 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 61/1000
# 2/2 - 0s - loss: 0.8273 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8538 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 62/1000
# 2/2 - 0s - loss: 0.8239 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8505 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 63/1000
# 2/2 - 0s - loss: 0.8202 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8480 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 64/1000
# 2/2 - 0s - loss: 0.8169 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8454 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 65/1000
# 2/2 - 0s - loss: 0.8140 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8422 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 66/1000
# 2/2 - 0s - loss: 0.8106 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8388 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 67/1000
# 2/2 - 0s - loss: 0.8070 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8359 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 50ms/epoch - 25ms/step
# Epoch 68/1000
# 2/2 - 0s - loss: 0.8048 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8331 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 69/1000
# 2/2 - 0s - loss: 0.8009 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8297 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 35ms/epoch - 18ms/step
# Epoch 70/1000
# 2/2 - 0s - loss: 0.7979 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8267 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 71/1000
# 2/2 - 0s - loss: 0.7948 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8241 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 72/1000
# 2/2 - 0s - loss: 0.7914 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8214 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 51ms/epoch - 26ms/step
# Epoch 73/1000
# 2/2 - 0s - loss: 0.7884 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8179 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 74/1000
# 2/2 - 0s - loss: 0.7852 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8146 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 75/1000
# 2/2 - 0s - loss: 0.7825 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8116 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 76/1000
# 2/2 - 0s - loss: 0.7796 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8090 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 77/1000
# 2/2 - 0s - loss: 0.7764 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8069 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 35ms/epoch - 18ms/step
# Epoch 78/1000
# 2/2 - 0s - loss: 0.7739 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.8034 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 35ms/epoch - 18ms/step
# Epoch 79/1000
# 2/2 - 0s - loss: 0.7707 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7999 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 80/1000
# 2/2 - 0s - loss: 0.7680 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7963 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 35ms/epoch - 18ms/step
# Epoch 81/1000
# 2/2 - 0s - loss: 0.7652 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7936 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 82/1000
# 2/2 - 0s - loss: 0.7628 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7912 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 83/1000
# 2/2 - 0s - loss: 0.7596 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7881 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 84/1000
# 2/2 - 0s - loss: 0.7570 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7846 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 85/1000
# 2/2 - 0s - loss: 0.7545 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7808 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 40ms/epoch - 20ms/step
# Epoch 86/1000
# 2/2 - 0s - loss: 0.7520 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7776 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 87/1000
# 2/2 - 0s - loss: 0.7492 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7751 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 88/1000
# 2/2 - 0s - loss: 0.7467 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7724 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 89/1000
# 2/2 - 0s - loss: 0.7445 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7698 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 90/1000
# 2/2 - 0s - loss: 0.7419 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7677 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 91/1000
# 2/2 - 0s - loss: 0.7394 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7646 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 92/1000
# 2/2 - 0s - loss: 0.7375 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7610 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 35ms/epoch - 18ms/step
# Epoch 93/1000
# 2/2 - 0s - loss: 0.7350 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7582 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 94/1000
# 2/2 - 0s - loss: 0.7323 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7557 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 95/1000
# 2/2 - 0s - loss: 0.7296 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7538 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 96/1000
# 2/2 - 0s - loss: 0.7272 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7518 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 97/1000
# 2/2 - 0s - loss: 0.7251 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7480 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 98/1000
# 2/2 - 0s - loss: 0.7222 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7442 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 99/1000
# 2/2 - 0s - loss: 0.7200 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7404 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 100/1000
# 2/2 - 0s - loss: 0.7181 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7373 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 101/1000
# 2/2 - 0s - loss: 0.7158 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7347 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 102/1000
# 2/2 - 0s - loss: 0.7138 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7324 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 103/1000
# 2/2 - 0s - loss: 0.7109 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7309 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 52ms/epoch - 26ms/step
# Epoch 104/1000
# 2/2 - 0s - loss: 0.7084 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7298 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 105/1000
# 2/2 - 0s - loss: 0.7063 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7284 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 106/1000
# 2/2 - 0s - loss: 0.7036 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7253 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 40ms/epoch - 20ms/step
# Epoch 107/1000
# 2/2 - 0s - loss: 0.7010 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7216 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 108/1000
# 2/2 - 0s - loss: 0.6986 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7183 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 109/1000
# 2/2 - 0s - loss: 0.6964 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7154 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 110/1000
# 2/2 - 0s - loss: 0.6942 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7130 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 111/1000
# 2/2 - 0s - loss: 0.6918 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7124 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 112/1000
# 2/2 - 0s - loss: 0.6890 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7121 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 113/1000
# 2/2 - 0s - loss: 0.6875 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7110 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 114/1000
# 2/2 - 0s - loss: 0.6851 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7089 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 115/1000
# 2/2 - 0s - loss: 0.6832 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7062 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 116/1000
# 2/2 - 0s - loss: 0.6816 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7040 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 34ms/epoch - 17ms/step
# Epoch 117/1000
# 2/2 - 0s - loss: 0.6797 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7034 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 52ms/epoch - 26ms/step
# Epoch 118/1000
# 2/2 - 0s - loss: 0.6774 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7034 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 119/1000
# 2/2 - 0s - loss: 0.6752 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7039 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 120/1000
# 2/2 - 0s - loss: 0.6737 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7038 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 121/1000
# 2/2 - 0s - loss: 0.6725 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.7022 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 122/1000
# 2/2 - 0s - loss: 0.6704 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6998 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 123/1000
# 2/2 - 0s - loss: 0.6689 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6975 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 124/1000
# 2/2 - 0s - loss: 0.6672 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6963 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 125/1000
# 2/2 - 0s - loss: 0.6654 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6960 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 126/1000
# 2/2 - 0s - loss: 0.6636 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6955 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 127/1000
# 2/2 - 0s - loss: 0.6622 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6932 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 128/1000
# 2/2 - 0s - loss: 0.6603 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6907 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 129/1000
# 2/2 - 0s - loss: 0.6589 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6888 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 130/1000
# 2/2 - 0s - loss: 0.6574 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6881 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 131/1000
# 2/2 - 0s - loss: 0.6558 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6881 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 46ms/epoch - 23ms/step
# Epoch 132/1000
# 2/2 - 0s - loss: 0.6544 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6863 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 133/1000
# 2/2 - 0s - loss: 0.6529 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6832 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 134/1000
# 2/2 - 0s - loss: 0.6511 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6816 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 135/1000
# 2/2 - 0s - loss: 0.6497 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6811 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 136/1000
# 2/2 - 0s - loss: 0.6483 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6802 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 46ms/epoch - 23ms/step
# Epoch 137/1000
# 2/2 - 0s - loss: 0.6471 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6782 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 138/1000
# 2/2 - 0s - loss: 0.6454 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6767 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 139/1000
# 2/2 - 0s - loss: 0.6441 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6753 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 140/1000
# 2/2 - 0s - loss: 0.6428 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6739 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 141/1000
# 2/2 - 0s - loss: 0.6413 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6731 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 47ms/epoch - 23ms/step
# Epoch 142/1000
# 2/2 - 0s - loss: 0.6400 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6720 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 143/1000
# 2/2 - 0s - loss: 0.6386 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6702 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 35ms/epoch - 18ms/step
# Epoch 144/1000
# 2/2 - 0s - loss: 0.6374 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6692 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 145/1000
# 2/2 - 0s - loss: 0.6359 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6689 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 146/1000
# 2/2 - 0s - loss: 0.6347 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6675 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 147/1000
# 2/2 - 0s - loss: 0.6336 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6657 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 148/1000
# 2/2 - 0s - loss: 0.6321 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6643 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 149/1000
# 2/2 - 0s - loss: 0.6307 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6620 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 150/1000
# 2/2 - 0s - loss: 0.6297 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6608 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 151/1000
# 2/2 - 0s - loss: 0.6284 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6612 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 152/1000
# 2/2 - 0s - loss: 0.6271 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6608 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 153/1000
# 2/2 - 0s - loss: 0.6263 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6591 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 154/1000
# 2/2 - 0s - loss: 0.6244 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6568 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 155/1000
# 2/2 - 0s - loss: 0.6235 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6544 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 156/1000
# 2/2 - 0s - loss: 0.6232 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6532 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 157/1000
# 2/2 - 0s - loss: 0.6223 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6525 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 158/1000
# 2/2 - 0s - loss: 0.6212 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6520 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 42ms/epoch - 21ms/step
# Epoch 159/1000
# 2/2 - 0s - loss: 0.6198 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6521 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 160/1000
# 2/2 - 0s - loss: 0.6181 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6529 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 161/1000
# 2/2 - 0s - loss: 0.6168 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6543 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 162/1000
# 2/2 - 0s - loss: 0.6158 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6551 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 163/1000
# 2/2 - 0s - loss: 0.6163 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6543 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 164/1000
# 2/2 - 0s - loss: 0.6148 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6523 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 45ms/epoch - 23ms/step
# Epoch 165/1000
# 2/2 - 0s - loss: 0.6129 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6487 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 46ms/epoch - 23ms/step
# Epoch 166/1000
# 2/2 - 0s - loss: 0.6117 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6465 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 167/1000
# 2/2 - 0s - loss: 0.6116 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6456 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 168/1000
# 2/2 - 0s - loss: 0.6101 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6470 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 169/1000
# 2/2 - 0s - loss: 0.6085 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6495 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 170/1000
# 2/2 - 0s - loss: 0.6079 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6493 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 41ms/epoch - 21ms/step
# Epoch 171/1000
# 2/2 - 0s - loss: 0.6072 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6460 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 172/1000
# 2/2 - 0s - loss: 0.6055 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6432 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 173/1000
# 2/2 - 0s - loss: 0.6052 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6415 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 174/1000
# 2/2 - 0s - loss: 0.6048 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6412 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 175/1000
# 2/2 - 0s - loss: 0.6036 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6418 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 176/1000
# 2/2 - 0s - loss: 0.6022 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6434 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 40ms/epoch - 20ms/step
# Epoch 177/1000
# 2/2 - 0s - loss: 0.6008 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6437 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 178/1000
# 2/2 - 0s - loss: 0.6004 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6428 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 179/1000
# 2/2 - 0s - loss: 0.5993 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6411 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 180/1000
# 2/2 - 0s - loss: 0.5980 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6401 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 40ms/epoch - 20ms/step
# Epoch 181/1000
# 2/2 - 0s - loss: 0.5973 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6394 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 41ms/epoch - 20ms/step
# Epoch 182/1000
# 2/2 - 0s - loss: 0.5965 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6369 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 20ms/step
# Epoch 183/1000
# 2/2 - 0s - loss: 0.5956 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6355 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 19ms/step
# Epoch 184/1000
# 2/2 - 0s - loss: 0.5954 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6350 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 39ms/epoch - 19ms/step
# Epoch 185/1000
# 2/2 - 0s - loss: 0.5939 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6366 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 37ms/epoch - 18ms/step
# Epoch 186/1000
# 2/2 - 0s - loss: 0.5937 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6369 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 187/1000
# 2/2 - 0s - loss: 0.5929 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6361 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 38ms/epoch - 19ms/step
# Epoch 188/1000
# 2/2 - 0s - loss: 0.5917 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6342 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 189/1000
# 2/2 - 0s - loss: 0.5908 - accuracy: 0.7500 - false_negatives_5: 0.0000e+00 - false_positives_5: 12.0000 - val_loss: 0.6325 - val_accuracy: 0.7059 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 5.0000 - 36ms/epoch - 18ms/step
# Epoch 190/1000
# ...
# Epoch 938/1000
# 2/2 - 0s - loss: 0.3747 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5672 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 939/1000
# 2/2 - 0s - loss: 0.3749 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5583 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 940/1000
# 2/2 - 0s - loss: 0.3768 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5600 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 941/1000
# 2/2 - 0s - loss: 0.3765 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5665 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 942/1000
# 2/2 - 0s - loss: 0.3756 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5749 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 943/1000
# 2/2 - 0s - loss: 0.3755 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5793 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 944/1000
# 2/2 - 0s - loss: 0.3756 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5790 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 945/1000
# 2/2 - 0s - loss: 0.3757 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5733 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 946/1000
# 2/2 - 0s - loss: 0.3744 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5619 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 947/1000
# 2/2 - 0s - loss: 0.3807 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5577 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 948/1000
# 2/2 - 0s - loss: 0.3785 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5669 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 949/1000
# 2/2 - 0s - loss: 0.3754 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5813 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 950/1000
# 2/2 - 0s - loss: 0.3746 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5919 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 951/1000
# 2/2 - 0s - loss: 0.3770 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5905 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 41ms/epoch - 21ms/step
# Epoch 952/1000
# 2/2 - 0s - loss: 0.3758 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5790 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 41ms/epoch - 20ms/step
# Epoch 953/1000
# 2/2 - 0s - loss: 0.3728 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5697 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 954/1000
# 2/2 - 0s - loss: 0.3744 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5639 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 955/1000
# 2/2 - 0s - loss: 0.3747 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5652 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 956/1000
# 2/2 - 0s - loss: 0.3730 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5703 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 957/1000
# 2/2 - 0s - loss: 0.3723 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5787 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 958/1000
# 2/2 - 0s - loss: 0.3740 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5792 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 959/1000
# 2/2 - 0s - loss: 0.3732 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5693 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 960/1000
# 2/2 - 0s - loss: 0.3726 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5602 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 961/1000
# 2/2 - 0s - loss: 0.3731 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5594 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 962/1000
# 2/2 - 0s - loss: 0.3730 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5646 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 37ms/epoch - 18ms/step
# Epoch 963/1000
# 2/2 - 0s - loss: 0.3713 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5754 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 964/1000
# 2/2 - 0s - loss: 0.3710 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5818 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 965/1000
# 2/2 - 0s - loss: 0.3720 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5802 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 966/1000
# 2/2 - 0s - loss: 0.3712 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5715 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 967/1000
# 2/2 - 0s - loss: 0.3724 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5604 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 968/1000
# 2/2 - 0s - loss: 0.3725 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5615 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 969/1000
# 2/2 - 0s - loss: 0.3706 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5644 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 970/1000
# 2/2 - 0s - loss: 0.3706 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5691 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 971/1000
# 2/2 - 0s - loss: 0.3712 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5735 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 972/1000
# 2/2 - 0s - loss: 0.3710 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5708 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 41ms/epoch - 20ms/step
# Epoch 973/1000
# 2/2 - 0s - loss: 0.3696 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5684 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 974/1000
# 2/2 - 0s - loss: 0.3693 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5691 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 975/1000
# 2/2 - 0s - loss: 0.3697 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5718 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 976/1000
# 2/2 - 0s - loss: 0.3701 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5753 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 977/1000
# 2/2 - 0s - loss: 0.3686 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5722 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 978/1000
# 2/2 - 0s - loss: 0.3687 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5703 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 979/1000
# 2/2 - 0s - loss: 0.3686 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5664 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 980/1000
# 2/2 - 0s - loss: 0.3684 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5629 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 981/1000
# 2/2 - 0s - loss: 0.3690 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 982/1000
# 2/2 - 0s - loss: 0.3679 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5646 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 983/1000
# 2/2 - 0s - loss: 0.3680 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5699 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 984/1000
# 2/2 - 0s - loss: 0.3697 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5675 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 985/1000
# 2/2 - 0s - loss: 0.3675 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5589 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 986/1000
# 2/2 - 0s - loss: 0.3677 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5569 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 41ms/epoch - 20ms/step
# Epoch 987/1000
# 2/2 - 0s - loss: 0.3684 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5581 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 988/1000
# 2/2 - 0s - loss: 0.3688 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5607 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 989/1000
# 2/2 - 0s - loss: 0.3676 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5578 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 990/1000
# 2/2 - 0s - loss: 0.3700 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5620 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 991/1000
# 2/2 - 0s - loss: 0.3686 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5562 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 41ms/epoch - 20ms/step
# Epoch 992/1000
# 2/2 - 0s - loss: 0.3670 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5595 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 993/1000
# 2/2 - 0s - loss: 0.3665 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5665 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 994/1000
# 2/2 - 0s - loss: 0.3659 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5670 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 995/1000
# 2/2 - 0s - loss: 0.3664 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5683 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 996/1000
# 2/2 - 0s - loss: 0.3669 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5653 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 997/1000
# 2/2 - 0s - loss: 0.3669 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5639 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 998/1000
# 2/2 - 0s - loss: 0.3658 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5625 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 999/1000
# 2/2 - 0s - loss: 0.3656 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5644 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 1000/1000
# 2/2 - 0s - loss: 0.3655 - accuracy: 0.9583 - false_negatives_5: 1.0000 - false_positives_5: 1.0000 - val_loss: 0.5619 - val_accuracy: 0.9412 - val_false_negatives_5: 0.0000e+00 - val_false_positives_5: 1.0000 - 39ms/epoch - 20ms/step
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6420 - accuracy: 0.8824 - false_negatives_5: 1.0000 - false_positives_5: 1.0000
# Test Loss: 0.6420
# Test Accuracy: 88.24%
# False Negatives: 1
# False Positives: 1
# 1/1 [==============================] - 0s 68ms/step
# Confusion Matrix:
# [[ 4  1]
#  [ 1 11]]

# %%
del model
